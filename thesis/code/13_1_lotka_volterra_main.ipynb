# %% [markdown]
# # Notebook Introduction
#
# Consider the Lotka-Volterra equations for a predator-prey dynamics:
#
# $$
# \begin{align}
# & \dot x = \alpha x - \gamma xy \\
# & \dot y = -\beta y + \eta (\gamma xy)
# \end{align}
# $$
#
# Suppose we only know $\alpha, \beta$ and $\eta$, how can we approximate the term $\gamma xy$? In this case we will use and implement the *Universal Differential Equations* according to [1] in Python.
#
# In particular, we will:
# 1. Generate a synthetic dataset by fixing the parameters first
# 2. Consider the L-V equations only with $\alpha, \beta, \eta$ known; the term $\gamma xy$ will be approximated with a Neural Network defined as $\texttt{NN}(\theta, t)$
# 3. Train the Neural Network with the method described in the paper, in particular using numerical integration of ODEs (Newton's first-order method)
#
# The loss used to train the NN will be the MSE loss, defined as
#
# $$
# \mathcal L_{\texttt{MSE} }(\theta) := \frac{1}{N} \sum_{i = 1, \ldots, n} [(\hat x_\theta(t_i) - x_i)^2 + (\hat y_\theta(t_i) - y_i)^2]
# $$
#
# Where $\hat x_\theta, \hat y_\theta$ are the solutions of the following parametrised DE in a certain time interval $[0, T]$:
#
# $$
# \begin{align}
# & \dot x = \alpha x - \texttt{NN}(\theta, t)[1] \\
# & \dot y = -\beta y + \cdot \texttt{NN}(\theta, t)[0]
# \end{align}
# $$
#
#
# > *Remark.* Our approach will differ from [1] as we will approximate the term $\gamma xy$ with *only one* neural network, instead of two. We consider this approach to be better and leverage our knowledge of the system further.
#
# Moreover the neural network will have two inputs and two outputs, one for each component of the dynamical system.
#
# In the end, we will compare the results with the ones presented in the paper.

# %%
# Libraries
import numpy as np 
from scipy.integrate import solve_ivp
import matplotlib.pyplot as plt
from torch import nn, optim 
import torch
from torchdiffeq import odeint
import pysindy as ps

# %%
# Part 1: Synthetic Data Generation

alpha = 1.3
delta = 1.8
beta = 0.9
gamma = 0.8

def lotka_volterra(t, data, a, d, b, gamma):
    x = data[0]
    y = data[1]
    return np.array([a * x - b * x * y, 
                    -d * y + gamma * x * y])

x0 = (0.44249296, 4.6280594)

TMAX = 3

sol = solve_ivp(lotka_volterra, t_span = [0, TMAX], t_eval=np.arange(0, TMAX, 0.01), args= (alpha, delta, beta, gamma), y0 = x0, rtol=1e-9, atol=1e-9)
data = sol.y

T = sol.t
X = data[0]
Y = data[1]

plt.plot(T, X, "--", label="True X")
plt.plot(T, Y, "--", label="True Y")

T_train = T[:300:10]
X_train = X[:300:10]
Y_train = Y[:300:10]

plt.scatter(T_train, X_train, label="Training Data X")
plt.scatter(T_train, Y_train, label="Training Data Y")

plt.legend()

plt.show()

# %%
# Part 1: Synthetic Data Generation
fig, ax0 = plt.subplots(1, 1, figsize=(15, 3))

ax0.plot(T, X, label="X", color='red')
ax0.plot(T, Y, label="Y", color='blue')

# %%
# Part 1: Synthetic Data Generation
fig, axes = plt.subplots(1, 2, figsize=(12, 5))
ax0 = axes[0]
ax1 = axes[1]

ax0.plot(T, X, label="X", color='red')
ax0.plot(T, Y, label="Y", color='blue')


ax0.legend()

ax0.set_xlabel("t")
ax0.set_ylabel("size")
ax0.set_title("Time series")

ax1.plot(X, Y)
ax1.set_xlabel("X")
ax1.set_ylabel("Y")
ax1.set_title("Phase diagram")

fig.suptitle(fr"Lotka-Volterra for $\alpha={alpha}, \beta={beta}, \delta={delta}, \gamma={gamma}$")

plt.show()

# %%
# Define UDE

class universal_LV(nn.Module):
    def __init__(self, alpha, delta):
        super().__init__()
        self.alpha = alpha
        self.delta = delta
        
        self.net = nn.Sequential(
            nn.Linear(2, 32),
            nn.SiLU(),
            nn.Linear(32, 32),
            nn.SiLU(),
            nn.Linear(32, 32),
            nn.SiLU(),
            nn.Linear(32, 32),
            nn.SiLU(),
            nn.Linear(32, 1), # We do 32 -> 1 -> 2 so the NN will try to learn beta, gamma implicitly!
            nn.Linear(1, 2)
        ) 

    def forward(self, t, data):
        out_net = self.net(data)
        x = data[0]
        y = data[1]

        summ = torch.tensor([self.alpha*x, -self.delta*y], dtype=torch.float32)

        out_net *= torch.tensor([-1, 1])

        return out_net + summ

# %%
my_lv = universal_LV(alpha, delta)

# %%
my_lv.load_state_dict(torch.load("./models_weights/my_lv_trained.eee"))
# Out:
# <All keys matched successfully>

# %%
# Train UDE network to training data
lr = 0.03
optimizer = torch.optim.Adam(my_lv.net.parameters(), lr)

for EPOCH in range(1, 1000):
    optimizer.zero_grad()
    my_lv.zero_grad()

    # get forward solution
    info = odeint(my_lv, torch.tensor(x0, dtype=torch.float32), torch.tensor(T_train, dtype=torch.float32),
                  rtol=1e-7, atol=1e-7, method='dopri5')

    # calculate loss

    loss = torch.tensor([.0, .0])

    for i, (x, y) in enumerate(zip(X_train, Y_train)):
        data = torch.tensor([x, y], dtype=torch.float32)
        loss += torch.pow(
            info[i]-data,
            torch.tensor([2., 2.])
        )

    loss /= T_train.shape[0]

    loss_norm = loss.mean()

    loss_norm.backward()

    optimizer.step()

    print(f"EPOCH {EPOCH}, LOSS: {loss_norm}")
# Out:
# EPOCH 1, LOSS: 77.35200500488281
# EPOCH 2, LOSS: 10.0615873336792
# EPOCH 3, LOSS: 48.71004867553711
# EPOCH 4, LOSS: 11.032272338867188
# EPOCH 5, LOSS: 0.47057244181632996
# EPOCH 6, LOSS: 0.47658243775367737
# EPOCH 7, LOSS: 2.421884298324585
# EPOCH 8, LOSS: 0.762167751789093
# EPOCH 9, LOSS: 0.06339795142412186
# EPOCH 10, LOSS: 0.030147969722747803
# EPOCH 11, LOSS: 0.06255505234003067
# EPOCH 12, LOSS: 0.08054625242948532
# EPOCH 13, LOSS: 0.0881943553686142
# EPOCH 14, LOSS: 0.09001634269952774
# EPOCH 15, LOSS: 0.08840733021497726
# EPOCH 16, LOSS: 0.08476261794567108
# EPOCH 17, LOSS: 0.08000361174345016
# EPOCH 18, LOSS: 0.07478252798318863
# EPOCH 19, LOSS: 0.06957093626260757
# EPOCH 20, LOSS: 0.06470496952533722
# EPOCH 21, LOSS: 0.06041276827454567
# EPOCH 22, LOSS: 0.05683314427733421
# EPOCH 23, LOSS: 0.054029274731874466
# EPOCH 24, LOSS: 0.051999978721141815
# EPOCH 25, LOSS: 0.05069031938910484
# EPOCH 26, LOSS: 0.05000164359807968
# EPOCH 964, LOSS: 0.0011462713591754436
# EPOCH 965, LOSS: 0.0010283715091645718
# EPOCH 966, LOSS: 0.0008803040254861116
# EPOCH 967, LOSS: 0.0007883900543674827
# EPOCH 968, LOSS: 0.0010890646371990442
# EPOCH 969, LOSS: 0.0008083029533736408
# EPOCH 970, LOSS: 0.0012308239238336682
# EPOCH 971, LOSS: 0.0014136991230770946
# EPOCH 972, LOSS: 0.0013108967104926705
# EPOCH 973, LOSS: 0.00216318154707551
# EPOCH 974, LOSS: 0.0012943325564265251
# EPOCH 975, LOSS: 0.002852269448339939
# EPOCH 976, LOSS: 0.0009614675655029714
# EPOCH 977, LOSS: 0.004780507180839777
# EPOCH 978, LOSS: 0.0035344904754310846
# EPOCH 979, LOSS: 0.018429290503263474
# EPOCH 980, LOSS: 0.041603829711675644
# EPOCH 981, LOSS: 0.01898837834596634
# EPOCH 982, LOSS: 0.003500523744150996
# EPOCH 983, LOSS: 0.002939869649708271
# EPOCH 984, LOSS: 0.003526862943544984
# EPOCH 985, LOSS: 0.0005922289565205574
# EPOCH 986, LOSS: 0.003966701216995716
# EPOCH 987, LOSS: 0.002480745315551758
# EPOCH 988, LOSS: 0.0015673902817070484
# EPOCH 989, LOSS: 0.002087540226057172
# EPOCH 990, LOSS: 0.002865458372980356
# EPOCH 991, LOSS: 0.004359503276646137
# EPOCH 992, LOSS: 0.005264379549771547
# EPOCH 993, LOSS: 0.004464993253350258
# EPOCH 994, LOSS: 0.0022651287727057934
# EPOCH 995, LOSS: 0.0012446186738088727
# EPOCH 996, LOSS: 0.002517109736800194
# EPOCH 997, LOSS: 0.0018748943693935871
# EPOCH 998, LOSS: 0.0008947747992351651
# EPOCH 999, LOSS: 0.0009759246604517102

# %%
pred = odeint(my_lv, torch.tensor(x0, dtype=torch.float32), torch.tensor(T_train, dtype=torch.float32))

# %%
plt.scatter(T_train, X_train,label="Training Data X")
plt.scatter(T_train, Y_train,label="Training Data Y")

plt.plot(T_train, pred[:, 0].detach().numpy(), label="Learned X")
plt.plot(T_train, pred[:, 1].detach().numpy(), label="Learned Y")

plt.legend()

plt.show()

# %%
# try it with NDEs

class neural_LV(nn.Module):
    # other case: full NN approach
    def __init__(self):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(2, 16),
            nn.LeakyReLU(),
            nn.Linear(16, 32),
            nn.LeakyReLU(),
            nn.Linear(32, 32),
            nn.Tanh(),
            nn.Linear(32, 32),
            nn.LeakyReLU(),
            nn.Linear(32, 16), 
            nn.LeakyReLU(),
            nn.Linear(16, 2)
        ) 

    def forward(self, t, data):
        return self.net(data)

# %%
my_neural_lv = neural_LV()
my_neural_lv = my_neural_lv

from tqdm import tqdm 

lr = 0.005
n_optimizer = torch.optim.Adam(my_neural_lv.net.parameters(), lr)

x0_torch = torch.tensor(x0, dtype=torch.float32)
T_train_torch = torch.tensor(T_train, dtype=torch.float32)
Y_train_torch = torch.tensor(Y_train, dtype=torch.float32)
X_train_torch = torch.tensor(X_train, dtype=torch.float32)

for EPOCH in (range(1, 1000)):
    n_optimizer.zero_grad()

    # get forward solution
    info = odeint(my_neural_lv, x0_torch, T_train_torch,
                  rtol=1e-5, atol=1e-5, method='rk4')

    # calculate loss
    loss_norm = torch.norm((info - torch.stack([X_train_torch, Y_train_torch], dim=1)), 2)**2
    loss_norm = loss_norm / T_train.shape[0]
    loss_norm.backward()

    n_optimizer.step()

    with torch.no_grad():
        
        print(f"Epoch {EPOCH}: MSE Loss (L2 norm)= {torch.norm(loss_norm, 2):.3E}")
# Out:
# Epoch 1: MSE Loss (L2 norm)= 8.504E+00
# Epoch 2: MSE Loss (L2 norm)= 8.118E+00
# Epoch 3: MSE Loss (L2 norm)= 7.622E+00
# Epoch 4: MSE Loss (L2 norm)= 6.997E+00
# Epoch 5: MSE Loss (L2 norm)= 6.178E+00
# Epoch 6: MSE Loss (L2 norm)= 5.258E+00
# Epoch 7: MSE Loss (L2 norm)= 4.275E+00
# Epoch 8: MSE Loss (L2 norm)= 3.254E+00
# Epoch 9: MSE Loss (L2 norm)= 2.254E+00
# Epoch 10: MSE Loss (L2 norm)= 1.378E+00
# Epoch 11: MSE Loss (L2 norm)= 7.317E-01
# Epoch 12: MSE Loss (L2 norm)= 3.770E-01
# Epoch 13: MSE Loss (L2 norm)= 2.943E-01
# Epoch 14: MSE Loss (L2 norm)= 3.466E-01
# Epoch 15: MSE Loss (L2 norm)= 3.946E-01
# Epoch 16: MSE Loss (L2 norm)= 3.988E-01
# Epoch 17: MSE Loss (L2 norm)= 3.755E-01
# Epoch 18: MSE Loss (L2 norm)= 3.496E-01
# Epoch 19: MSE Loss (L2 norm)= 3.361E-01
# Epoch 20: MSE Loss (L2 norm)= 3.369E-01
# Epoch 21: MSE Loss (L2 norm)= 3.462E-01
# Epoch 22: MSE Loss (L2 norm)= 3.539E-01
# Epoch 23: MSE Loss (L2 norm)= 3.526E-01
# Epoch 24: MSE Loss (L2 norm)= 3.398E-01
# Epoch 25: MSE Loss (L2 norm)= 3.172E-01
# Epoch 26: MSE Loss (L2 norm)= 2.880E-01
# Epoch 27: MSE Loss (L2 norm)= 2.558E-01
# Epoch 28: MSE Loss (L2 norm)= 2.241E-01
# Epoch 29: MSE Loss (L2 norm)= 1.951E-01
# Epoch 30: MSE Loss (L2 norm)= 1.711E-01
# Epoch 31: MSE Loss (L2 norm)= 1.521E-01
# Epoch 32: MSE Loss (L2 norm)= 1.377E-01
# Epoch 33: MSE Loss (L2 norm)= 1.271E-01
# Epoch 34: MSE Loss (L2 norm)= 1.188E-01
# Epoch 35: MSE Loss (L2 norm)= 1.113E-01
# Epoch 36: MSE Loss (L2 norm)= 1.038E-01
# Epoch 37: MSE Loss (L2 norm)= 9.542E-02
# Epoch 38: MSE Loss (L2 norm)= 8.679E-02
# Epoch 39: MSE Loss (L2 norm)= 7.832E-02
# Epoch 40: MSE Loss (L2 norm)= 7.074E-02
# Epoch 41: MSE Loss (L2 norm)= 6.451E-02
# Epoch 42: MSE Loss (L2 norm)= 5.991E-02
# Epoch 43: MSE Loss (L2 norm)= 5.695E-02
# Epoch 44: MSE Loss (L2 norm)= 5.522E-02
# Epoch 45: MSE Loss (L2 norm)= 5.418E-02
# Epoch 46: MSE Loss (L2 norm)= 5.315E-02
# Epoch 47: MSE Loss (L2 norm)= 5.140E-02
# Epoch 48: MSE Loss (L2 norm)= 4.848E-02
# Epoch 49: MSE Loss (L2 norm)= 4.440E-02
# Epoch 50: MSE Loss (L2 norm)= 3.961E-02
# Epoch 51: MSE Loss (L2 norm)= 3.481E-02
# Epoch 52: MSE Loss (L2 norm)= 3.059E-02
# Epoch 53: MSE Loss (L2 norm)= 2.718E-02
# Epoch 54: MSE Loss (L2 norm)= 2.443E-02
# Epoch 55: MSE Loss (L2 norm)= 2.194E-02
# Epoch 56: MSE Loss (L2 norm)= 1.944E-02
# Epoch 57: MSE Loss (L2 norm)= 1.694E-02
# Epoch 58: MSE Loss (L2 norm)= 1.474E-02
# Epoch 59: MSE Loss (L2 norm)= 1.308E-02
# Epoch 60: MSE Loss (L2 norm)= 1.212E-02
# Epoch 61: MSE Loss (L2 norm)= 1.177E-02
# Epoch 62: MSE Loss (L2 norm)= 1.175E-02
# Epoch 63: MSE Loss (L2 norm)= 1.176E-02
# Epoch 64: MSE Loss (L2 norm)= 1.164E-02
# Epoch 65: MSE Loss (L2 norm)= 1.140E-02
# Epoch 66: MSE Loss (L2 norm)= 1.117E-02
# Epoch 67: MSE Loss (L2 norm)= 1.110E-02
# Epoch 68: MSE Loss (L2 norm)= 1.123E-02
# Epoch 69: MSE Loss (L2 norm)= 1.145E-02
# Epoch 70: MSE Loss (L2 norm)= 1.160E-02
# Epoch 71: MSE Loss (L2 norm)= 1.157E-02
# Epoch 72: MSE Loss (L2 norm)= 1.136E-02
# Epoch 73: MSE Loss (L2 norm)= 1.109E-02
# Epoch 74: MSE Loss (L2 norm)= 1.087E-02
# Epoch 75: MSE Loss (L2 norm)= 1.075E-02
# Epoch 76: MSE Loss (L2 norm)= 1.066E-02
# Epoch 77: MSE Loss (L2 norm)= 1.055E-02
# Epoch 78: MSE Loss (L2 norm)= 1.036E-02
# Epoch 79: MSE Loss (L2 norm)= 1.010E-02
# Epoch 80: MSE Loss (L2 norm)= 9.824E-03
# Epoch 81: MSE Loss (L2 norm)= 9.605E-03
# Epoch 82: MSE Loss (L2 norm)= 9.455E-03
# Epoch 83: MSE Loss (L2 norm)= 9.341E-03
# Epoch 84: MSE Loss (L2 norm)= 9.215E-03
# Epoch 85: MSE Loss (L2 norm)= 9.052E-03
# Epoch 86: MSE Loss (L2 norm)= 8.863E-03
# Epoch 87: MSE Loss (L2 norm)= 8.681E-03
# Epoch 88: MSE Loss (L2 norm)= 8.529E-03
# Epoch 89: MSE Loss (L2 norm)= 8.406E-03
# Epoch 90: MSE Loss (L2 norm)= 8.293E-03
# Epoch 91: MSE Loss (L2 norm)= 8.171E-03
# Epoch 92: MSE Loss (L2 norm)= 8.037E-03
# Epoch 93: MSE Loss (L2 norm)= 7.902E-03
# Epoch 94: MSE Loss (L2 norm)= 7.781E-03
# Epoch 95: MSE Loss (L2 norm)= 7.681E-03
# Epoch 96: MSE Loss (L2 norm)= 7.598E-03
# Epoch 97: MSE Loss (L2 norm)= 7.519E-03
# Epoch 98: MSE Loss (L2 norm)= 7.431E-03
# Epoch 99: MSE Loss (L2 norm)= 7.331E-03
# Epoch 100: MSE Loss (L2 norm)= 7.226E-03
# Epoch 101: MSE Loss (L2 norm)= 7.125E-03
# Epoch 102: MSE Loss (L2 norm)= 7.032E-03
# Epoch 103: MSE Loss (L2 norm)= 6.944E-03
# Epoch 104: MSE Loss (L2 norm)= 6.853E-03
# Epoch 105: MSE Loss (L2 norm)= 6.758E-03
# Epoch 106: MSE Loss (L2 norm)= 6.662E-03
# Epoch 107: MSE Loss (L2 norm)= 6.570E-03
# Epoch 108: MSE Loss (L2 norm)= 6.485E-03
# Epoch 109: MSE Loss (L2 norm)= 6.405E-03
# Epoch 110: MSE Loss (L2 norm)= 6.324E-03
# Epoch 111: MSE Loss (L2 norm)= 6.237E-03
# Epoch 112: MSE Loss (L2 norm)= 6.147E-03
# Epoch 113: MSE Loss (L2 norm)= 6.062E-03
# Epoch 114: MSE Loss (L2 norm)= 5.980E-03
# Epoch 115: MSE Loss (L2 norm)= 5.901E-03
# Epoch 116: MSE Loss (L2 norm)= 5.824E-03
# Epoch 117: MSE Loss (L2 norm)= 5.747E-03
# Epoch 118: MSE Loss (L2 norm)= 5.670E-03
# Epoch 119: MSE Loss (L2 norm)= 5.598E-03
# Epoch 120: MSE Loss (L2 norm)= 5.530E-03
# Epoch 121: MSE Loss (L2 norm)= 5.466E-03
# Epoch 122: MSE Loss (L2 norm)= 5.404E-03
# Epoch 123: MSE Loss (L2 norm)= 5.342E-03
# Epoch 124: MSE Loss (L2 norm)= 5.281E-03
# Epoch 125: MSE Loss (L2 norm)= 5.222E-03
# Epoch 126: MSE Loss (L2 norm)= 5.164E-03
# Epoch 127: MSE Loss (L2 norm)= 5.107E-03
# Epoch 128: MSE Loss (L2 norm)= 5.049E-03
# Epoch 129: MSE Loss (L2 norm)= 4.990E-03
# Epoch 130: MSE Loss (L2 norm)= 4.933E-03
# Epoch 131: MSE Loss (L2 norm)= 4.877E-03
# Epoch 132: MSE Loss (L2 norm)= 4.823E-03
# Epoch 133: MSE Loss (L2 norm)= 4.769E-03
# Epoch 134: MSE Loss (L2 norm)= 4.717E-03
# Epoch 135: MSE Loss (L2 norm)= 4.666E-03
# Epoch 136: MSE Loss (L2 norm)= 4.616E-03
# Epoch 137: MSE Loss (L2 norm)= 4.568E-03
# Epoch 138: MSE Loss (L2 norm)= 4.520E-03
# Epoch 139: MSE Loss (L2 norm)= 4.474E-03
# Epoch 140: MSE Loss (L2 norm)= 4.427E-03
# Epoch 141: MSE Loss (L2 norm)= 4.382E-03
# Epoch 142: MSE Loss (L2 norm)= 4.338E-03
# Epoch 143: MSE Loss (L2 norm)= 4.293E-03
# Epoch 144: MSE Loss (L2 norm)= 4.249E-03
# Epoch 145: MSE Loss (L2 norm)= 4.206E-03
# Epoch 146: MSE Loss (L2 norm)= 4.163E-03
# Epoch 147: MSE Loss (L2 norm)= 4.120E-03
# Epoch 148: MSE Loss (L2 norm)= 4.078E-03
# Epoch 149: MSE Loss (L2 norm)= 4.036E-03
# Epoch 150: MSE Loss (L2 norm)= 3.995E-03
# Epoch 151: MSE Loss (L2 norm)= 3.954E-03
# Epoch 152: MSE Loss (L2 norm)= 3.913E-03
# Epoch 153: MSE Loss (L2 norm)= 3.873E-03
# Epoch 154: MSE Loss (L2 norm)= 3.832E-03
# Epoch 155: MSE Loss (L2 norm)= 3.792E-03
# Epoch 156: MSE Loss (L2 norm)= 3.752E-03
# Epoch 157: MSE Loss (L2 norm)= 3.713E-03
# Epoch 158: MSE Loss (L2 norm)= 3.673E-03
# Epoch 159: MSE Loss (L2 norm)= 3.633E-03
# Epoch 160: MSE Loss (L2 norm)= 3.593E-03
# Epoch 161: MSE Loss (L2 norm)= 3.554E-03
# Epoch 162: MSE Loss (L2 norm)= 3.514E-03
# Epoch 163: MSE Loss (L2 norm)= 3.474E-03
# Epoch 164: MSE Loss (L2 norm)= 3.434E-03
# Epoch 165: MSE Loss (L2 norm)= 3.394E-03
# Epoch 166: MSE Loss (L2 norm)= 3.354E-03
# Epoch 167: MSE Loss (L2 norm)= 3.314E-03
# Epoch 168: MSE Loss (L2 norm)= 3.274E-03
# Epoch 169: MSE Loss (L2 norm)= 3.234E-03
# Epoch 170: MSE Loss (L2 norm)= 3.194E-03
# Epoch 171: MSE Loss (L2 norm)= 3.154E-03
# Epoch 172: MSE Loss (L2 norm)= 3.113E-03
# Epoch 173: MSE Loss (L2 norm)= 3.074E-03
# Epoch 174: MSE Loss (L2 norm)= 3.034E-03
# Epoch 175: MSE Loss (L2 norm)= 2.995E-03
# Epoch 176: MSE Loss (L2 norm)= 2.957E-03
# Epoch 177: MSE Loss (L2 norm)= 2.918E-03
# Epoch 178: MSE Loss (L2 norm)= 2.881E-03
# Epoch 179: MSE Loss (L2 norm)= 2.844E-03
# Epoch 180: MSE Loss (L2 norm)= 2.807E-03
# Epoch 181: MSE Loss (L2 norm)= 2.771E-03
# Epoch 182: MSE Loss (L2 norm)= 2.734E-03
# Epoch 183: MSE Loss (L2 norm)= 2.697E-03
# Epoch 184: MSE Loss (L2 norm)= 2.660E-03
# Epoch 185: MSE Loss (L2 norm)= 2.622E-03
# Epoch 186: MSE Loss (L2 norm)= 2.585E-03
# Epoch 187: MSE Loss (L2 norm)= 2.549E-03
# Epoch 188: MSE Loss (L2 norm)= 2.513E-03
# Epoch 189: MSE Loss (L2 norm)= 2.479E-03
# Epoch 190: MSE Loss (L2 norm)= 2.445E-03
# Epoch 191: MSE Loss (L2 norm)= 2.413E-03
# Epoch 192: MSE Loss (L2 norm)= 2.382E-03
# Epoch 193: MSE Loss (L2 norm)= 2.351E-03
# Epoch 194: MSE Loss (L2 norm)= 2.321E-03
# Epoch 195: MSE Loss (L2 norm)= 2.292E-03
# Epoch 196: MSE Loss (L2 norm)= 2.264E-03
# Epoch 197: MSE Loss (L2 norm)= 2.236E-03
# Epoch 198: MSE Loss (L2 norm)= 2.208E-03
# Epoch 199: MSE Loss (L2 norm)= 2.181E-03
# Epoch 200: MSE Loss (L2 norm)= 2.154E-03
# Epoch 201: MSE Loss (L2 norm)= 2.127E-03
# Epoch 202: MSE Loss (L2 norm)= 2.101E-03
# Epoch 203: MSE Loss (L2 norm)= 2.075E-03
# Epoch 204: MSE Loss (L2 norm)= 2.049E-03
# Epoch 205: MSE Loss (L2 norm)= 2.023E-03
# Epoch 206: MSE Loss (L2 norm)= 1.998E-03
# Epoch 207: MSE Loss (L2 norm)= 1.973E-03
# Epoch 208: MSE Loss (L2 norm)= 1.948E-03
# Epoch 209: MSE Loss (L2 norm)= 1.924E-03
# Epoch 210: MSE Loss (L2 norm)= 1.899E-03
# Epoch 211: MSE Loss (L2 norm)= 1.875E-03
# Epoch 212: MSE Loss (L2 norm)= 1.852E-03
# Epoch 213: MSE Loss (L2 norm)= 1.828E-03
# Epoch 214: MSE Loss (L2 norm)= 1.805E-03
# Epoch 215: MSE Loss (L2 norm)= 1.782E-03
# Epoch 216: MSE Loss (L2 norm)= 1.759E-03
# Epoch 217: MSE Loss (L2 norm)= 1.737E-03
# Epoch 218: MSE Loss (L2 norm)= 1.714E-03
# Epoch 219: MSE Loss (L2 norm)= 1.692E-03
# Epoch 220: MSE Loss (L2 norm)= 1.670E-03
# Epoch 221: MSE Loss (L2 norm)= 1.648E-03
# Epoch 222: MSE Loss (L2 norm)= 1.626E-03
# Epoch 223: MSE Loss (L2 norm)= 1.604E-03
# Epoch 224: MSE Loss (L2 norm)= 1.583E-03
# Epoch 225: MSE Loss (L2 norm)= 1.562E-03
# Epoch 226: MSE Loss (L2 norm)= 1.541E-03
# Epoch 227: MSE Loss (L2 norm)= 1.520E-03
# Epoch 228: MSE Loss (L2 norm)= 1.500E-03
# Epoch 229: MSE Loss (L2 norm)= 1.480E-03
# Epoch 230: MSE Loss (L2 norm)= 1.460E-03
# Epoch 231: MSE Loss (L2 norm)= 1.441E-03
# Epoch 232: MSE Loss (L2 norm)= 1.421E-03
# Epoch 233: MSE Loss (L2 norm)= 1.402E-03
# Epoch 234: MSE Loss (L2 norm)= 1.383E-03
# Epoch 235: MSE Loss (L2 norm)= 1.364E-03
# Epoch 236: MSE Loss (L2 norm)= 1.346E-03
# Epoch 237: MSE Loss (L2 norm)= 1.327E-03
# Epoch 238: MSE Loss (L2 norm)= 1.309E-03
# Epoch 239: MSE Loss (L2 norm)= 1.290E-03
# Epoch 240: MSE Loss (L2 norm)= 1.271E-03
# Epoch 241: MSE Loss (L2 norm)= 1.252E-03
# Epoch 242: MSE Loss (L2 norm)= 1.233E-03
# Epoch 243: MSE Loss (L2 norm)= 1.215E-03
# Epoch 244: MSE Loss (L2 norm)= 1.197E-03
# Epoch 245: MSE Loss (L2 norm)= 1.179E-03
# Epoch 246: MSE Loss (L2 norm)= 1.162E-03
# Epoch 247: MSE Loss (L2 norm)= 1.145E-03
# Epoch 248: MSE Loss (L2 norm)= 1.128E-03
# Epoch 249: MSE Loss (L2 norm)= 1.112E-03
# Epoch 250: MSE Loss (L2 norm)= 1.096E-03
# Epoch 251: MSE Loss (L2 norm)= 1.080E-03
# Epoch 252: MSE Loss (L2 norm)= 1.064E-03
# Epoch 253: MSE Loss (L2 norm)= 1.049E-03
# Epoch 254: MSE Loss (L2 norm)= 1.033E-03
# Epoch 255: MSE Loss (L2 norm)= 1.018E-03
# Epoch 256: MSE Loss (L2 norm)= 1.004E-03
# Epoch 257: MSE Loss (L2 norm)= 9.892E-04
# Epoch 258: MSE Loss (L2 norm)= 9.749E-04
# Epoch 259: MSE Loss (L2 norm)= 9.609E-04
# Epoch 260: MSE Loss (L2 norm)= 9.471E-04
# Epoch 261: MSE Loss (L2 norm)= 9.337E-04
# Epoch 262: MSE Loss (L2 norm)= 9.204E-04
# Epoch 263: MSE Loss (L2 norm)= 9.073E-04
# Epoch 264: MSE Loss (L2 norm)= 8.944E-04
# Epoch 265: MSE Loss (L2 norm)= 8.816E-04
# Epoch 266: MSE Loss (L2 norm)= 8.690E-04
# Epoch 267: MSE Loss (L2 norm)= 8.566E-04
# Epoch 268: MSE Loss (L2 norm)= 8.445E-04
# Epoch 269: MSE Loss (L2 norm)= 8.325E-04
# Epoch 270: MSE Loss (L2 norm)= 8.207E-04
# Epoch 271: MSE Loss (L2 norm)= 8.090E-04
# Epoch 272: MSE Loss (L2 norm)= 7.975E-04
# Epoch 273: MSE Loss (L2 norm)= 7.861E-04
# Epoch 274: MSE Loss (L2 norm)= 7.749E-04
# Epoch 275: MSE Loss (L2 norm)= 7.640E-04
# Epoch 276: MSE Loss (L2 norm)= 7.532E-04
# Epoch 277: MSE Loss (L2 norm)= 7.425E-04
# Epoch 278: MSE Loss (L2 norm)= 7.319E-04
# Epoch 279: MSE Loss (L2 norm)= 7.215E-04
# Epoch 280: MSE Loss (L2 norm)= 7.112E-04
# Epoch 281: MSE Loss (L2 norm)= 7.011E-04
# Epoch 282: MSE Loss (L2 norm)= 6.911E-04
# Epoch 283: MSE Loss (L2 norm)= 6.812E-04
# Epoch 284: MSE Loss (L2 norm)= 6.714E-04
# Epoch 285: MSE Loss (L2 norm)= 6.618E-04
# Epoch 286: MSE Loss (L2 norm)= 6.523E-04
# Epoch 287: MSE Loss (L2 norm)= 6.430E-04
# Epoch 288: MSE Loss (L2 norm)= 6.337E-04
# Epoch 289: MSE Loss (L2 norm)= 6.245E-04
# Epoch 290: MSE Loss (L2 norm)= 6.155E-04
# Epoch 291: MSE Loss (L2 norm)= 6.066E-04
# Epoch 292: MSE Loss (L2 norm)= 5.978E-04
# Epoch 293: MSE Loss (L2 norm)= 5.891E-04
# Epoch 294: MSE Loss (L2 norm)= 5.806E-04
# Epoch 295: MSE Loss (L2 norm)= 5.721E-04
# Epoch 296: MSE Loss (L2 norm)= 5.638E-04
# Epoch 297: MSE Loss (L2 norm)= 5.555E-04
# Epoch 298: MSE Loss (L2 norm)= 5.474E-04
# Epoch 299: MSE Loss (L2 norm)= 5.394E-04
# Epoch 300: MSE Loss (L2 norm)= 5.315E-04
# Epoch 301: MSE Loss (L2 norm)= 5.237E-04
# Epoch 302: MSE Loss (L2 norm)= 5.160E-04
# Epoch 303: MSE Loss (L2 norm)= 5.084E-04
# Epoch 304: MSE Loss (L2 norm)= 5.009E-04
# Epoch 305: MSE Loss (L2 norm)= 4.936E-04
# Epoch 306: MSE Loss (L2 norm)= 4.863E-04
# Epoch 307: MSE Loss (L2 norm)= 4.791E-04
# Epoch 308: MSE Loss (L2 norm)= 4.720E-04
# Epoch 309: MSE Loss (L2 norm)= 4.650E-04
# Epoch 310: MSE Loss (L2 norm)= 4.582E-04
# Epoch 311: MSE Loss (L2 norm)= 4.514E-04
# Epoch 312: MSE Loss (L2 norm)= 4.448E-04
# Epoch 313: MSE Loss (L2 norm)= 4.382E-04
# Epoch 314: MSE Loss (L2 norm)= 4.317E-04
# Epoch 315: MSE Loss (L2 norm)= 4.254E-04
# Epoch 316: MSE Loss (L2 norm)= 4.191E-04
# Epoch 317: MSE Loss (L2 norm)= 4.130E-04
# Epoch 318: MSE Loss (L2 norm)= 4.069E-04
# Epoch 319: MSE Loss (L2 norm)= 4.009E-04
# Epoch 320: MSE Loss (L2 norm)= 3.951E-04
# Epoch 321: MSE Loss (L2 norm)= 3.893E-04
# Epoch 322: MSE Loss (L2 norm)= 3.836E-04
# Epoch 323: MSE Loss (L2 norm)= 3.780E-04
# Epoch 324: MSE Loss (L2 norm)= 3.724E-04
# Epoch 325: MSE Loss (L2 norm)= 3.670E-04
# Epoch 326: MSE Loss (L2 norm)= 3.617E-04
# Epoch 327: MSE Loss (L2 norm)= 3.565E-04
# Epoch 328: MSE Loss (L2 norm)= 3.513E-04
# Epoch 329: MSE Loss (L2 norm)= 3.463E-04
# Epoch 330: MSE Loss (L2 norm)= 3.413E-04
# Epoch 331: MSE Loss (L2 norm)= 3.364E-04
# Epoch 332: MSE Loss (L2 norm)= 3.316E-04
# Epoch 333: MSE Loss (L2 norm)= 3.269E-04
# Epoch 334: MSE Loss (L2 norm)= 3.222E-04
# Epoch 335: MSE Loss (L2 norm)= 3.177E-04
# Epoch 336: MSE Loss (L2 norm)= 3.132E-04
# Epoch 337: MSE Loss (L2 norm)= 3.088E-04
# Epoch 338: MSE Loss (L2 norm)= 3.045E-04
# Epoch 339: MSE Loss (L2 norm)= 3.003E-04
# Epoch 340: MSE Loss (L2 norm)= 2.962E-04
# Epoch 341: MSE Loss (L2 norm)= 2.921E-04
# Epoch 342: MSE Loss (L2 norm)= 2.881E-04
# Epoch 343: MSE Loss (L2 norm)= 2.842E-04
# Epoch 344: MSE Loss (L2 norm)= 2.803E-04
# Epoch 345: MSE Loss (L2 norm)= 2.765E-04
# Epoch 346: MSE Loss (L2 norm)= 2.728E-04
# Epoch 347: MSE Loss (L2 norm)= 2.692E-04
# Epoch 348: MSE Loss (L2 norm)= 2.656E-04
# Epoch 349: MSE Loss (L2 norm)= 2.621E-04
# Epoch 350: MSE Loss (L2 norm)= 2.587E-04
# Epoch 351: MSE Loss (L2 norm)= 2.553E-04
# Epoch 352: MSE Loss (L2 norm)= 2.520E-04
# Epoch 353: MSE Loss (L2 norm)= 2.488E-04
# Epoch 354: MSE Loss (L2 norm)= 2.456E-04
# Epoch 355: MSE Loss (L2 norm)= 2.425E-04
# Epoch 356: MSE Loss (L2 norm)= 2.394E-04
# Epoch 357: MSE Loss (L2 norm)= 2.364E-04
# Epoch 358: MSE Loss (L2 norm)= 2.334E-04
# Epoch 359: MSE Loss (L2 norm)= 2.305E-04
# Epoch 360: MSE Loss (L2 norm)= 2.277E-04
# Epoch 361: MSE Loss (L2 norm)= 2.249E-04
# Epoch 362: MSE Loss (L2 norm)= 2.221E-04
# Epoch 363: MSE Loss (L2 norm)= 2.195E-04
# Epoch 364: MSE Loss (L2 norm)= 2.168E-04
# Epoch 365: MSE Loss (L2 norm)= 2.143E-04
# Epoch 366: MSE Loss (L2 norm)= 2.118E-04
# Epoch 367: MSE Loss (L2 norm)= 2.093E-04
# Epoch 368: MSE Loss (L2 norm)= 2.069E-04
# Epoch 369: MSE Loss (L2 norm)= 2.045E-04
# Epoch 370: MSE Loss (L2 norm)= 2.022E-04
# Epoch 371: MSE Loss (L2 norm)= 1.999E-04
# Epoch 372: MSE Loss (L2 norm)= 1.977E-04
# Epoch 373: MSE Loss (L2 norm)= 1.955E-04
# Epoch 374: MSE Loss (L2 norm)= 1.933E-04
# Epoch 375: MSE Loss (L2 norm)= 1.913E-04
# Epoch 376: MSE Loss (L2 norm)= 1.892E-04
# Epoch 377: MSE Loss (L2 norm)= 1.872E-04
# Epoch 378: MSE Loss (L2 norm)= 1.852E-04
# Epoch 379: MSE Loss (L2 norm)= 1.833E-04
# Epoch 380: MSE Loss (L2 norm)= 1.814E-04
# Epoch 381: MSE Loss (L2 norm)= 1.795E-04
# Epoch 382: MSE Loss (L2 norm)= 1.777E-04
# Epoch 383: MSE Loss (L2 norm)= 1.759E-04
# Epoch 384: MSE Loss (L2 norm)= 1.742E-04
# Epoch 385: MSE Loss (L2 norm)= 1.724E-04
# Epoch 386: MSE Loss (L2 norm)= 1.707E-04
# Epoch 387: MSE Loss (L2 norm)= 1.691E-04
# Epoch 388: MSE Loss (L2 norm)= 1.675E-04
# Epoch 389: MSE Loss (L2 norm)= 1.659E-04
# Epoch 390: MSE Loss (L2 norm)= 1.643E-04
# Epoch 391: MSE Loss (L2 norm)= 1.628E-04
# Epoch 392: MSE Loss (L2 norm)= 1.612E-04
# Epoch 393: MSE Loss (L2 norm)= 1.597E-04
# Epoch 394: MSE Loss (L2 norm)= 1.583E-04
# Epoch 395: MSE Loss (L2 norm)= 1.568E-04
# Epoch 396: MSE Loss (L2 norm)= 1.554E-04
# Epoch 397: MSE Loss (L2 norm)= 1.540E-04
# Epoch 398: MSE Loss (L2 norm)= 1.526E-04
# Epoch 399: MSE Loss (L2 norm)= 1.513E-04
# Epoch 400: MSE Loss (L2 norm)= 1.500E-04
# Epoch 401: MSE Loss (L2 norm)= 1.487E-04
# Epoch 402: MSE Loss (L2 norm)= 1.474E-04
# Epoch 403: MSE Loss (L2 norm)= 1.462E-04
# Epoch 404: MSE Loss (L2 norm)= 1.450E-04
# Epoch 405: MSE Loss (L2 norm)= 1.438E-04
# Epoch 406: MSE Loss (L2 norm)= 1.426E-04
# Epoch 407: MSE Loss (L2 norm)= 1.414E-04
# Epoch 408: MSE Loss (L2 norm)= 1.403E-04
# Epoch 409: MSE Loss (L2 norm)= 1.392E-04
# Epoch 410: MSE Loss (L2 norm)= 1.381E-04
# Epoch 411: MSE Loss (L2 norm)= 1.370E-04
# Epoch 412: MSE Loss (L2 norm)= 1.360E-04
# Epoch 413: MSE Loss (L2 norm)= 1.349E-04
# Epoch 414: MSE Loss (L2 norm)= 1.339E-04
# Epoch 415: MSE Loss (L2 norm)= 1.329E-04
# Epoch 416: MSE Loss (L2 norm)= 1.320E-04
# Epoch 417: MSE Loss (L2 norm)= 1.310E-04
# Epoch 418: MSE Loss (L2 norm)= 1.300E-04
# Epoch 419: MSE Loss (L2 norm)= 1.291E-04
# Epoch 420: MSE Loss (L2 norm)= 1.282E-04
# Epoch 421: MSE Loss (L2 norm)= 1.273E-04
# Epoch 422: MSE Loss (L2 norm)= 1.264E-04
# Epoch 423: MSE Loss (L2 norm)= 1.255E-04
# Epoch 424: MSE Loss (L2 norm)= 1.247E-04
# Epoch 425: MSE Loss (L2 norm)= 1.238E-04
# Epoch 426: MSE Loss (L2 norm)= 1.230E-04
# Epoch 427: MSE Loss (L2 norm)= 1.222E-04
# Epoch 428: MSE Loss (L2 norm)= 1.214E-04
# Epoch 429: MSE Loss (L2 norm)= 1.206E-04
# Epoch 430: MSE Loss (L2 norm)= 1.198E-04
# Epoch 431: MSE Loss (L2 norm)= 1.191E-04
# Epoch 432: MSE Loss (L2 norm)= 1.183E-04
# Epoch 433: MSE Loss (L2 norm)= 1.176E-04
# Epoch 434: MSE Loss (L2 norm)= 1.169E-04
# Epoch 435: MSE Loss (L2 norm)= 1.162E-04
# Epoch 436: MSE Loss (L2 norm)= 1.155E-04
# Epoch 437: MSE Loss (L2 norm)= 1.148E-04
# Epoch 438: MSE Loss (L2 norm)= 1.141E-04
# Epoch 439: MSE Loss (L2 norm)= 1.134E-04
# Epoch 440: MSE Loss (L2 norm)= 1.128E-04
# Epoch 441: MSE Loss (L2 norm)= 1.122E-04
# Epoch 442: MSE Loss (L2 norm)= 1.115E-04
# Epoch 443: MSE Loss (L2 norm)= 1.109E-04
# Epoch 444: MSE Loss (L2 norm)= 1.103E-04
# Epoch 445: MSE Loss (L2 norm)= 1.097E-04
# Epoch 446: MSE Loss (L2 norm)= 1.091E-04
# Epoch 447: MSE Loss (L2 norm)= 1.085E-04
# Epoch 448: MSE Loss (L2 norm)= 1.080E-04
# Epoch 449: MSE Loss (L2 norm)= 1.074E-04
# Epoch 450: MSE Loss (L2 norm)= 1.069E-04
# Epoch 451: MSE Loss (L2 norm)= 1.063E-04
# Epoch 452: MSE Loss (L2 norm)= 1.058E-04
# Epoch 453: MSE Loss (L2 norm)= 1.053E-04
# Epoch 454: MSE Loss (L2 norm)= 1.048E-04
# Epoch 455: MSE Loss (L2 norm)= 1.042E-04
# Epoch 456: MSE Loss (L2 norm)= 1.037E-04
# Epoch 457: MSE Loss (L2 norm)= 1.033E-04
# Epoch 458: MSE Loss (L2 norm)= 1.028E-04
# Epoch 459: MSE Loss (L2 norm)= 1.023E-04
# Epoch 460: MSE Loss (L2 norm)= 1.018E-04
# Epoch 461: MSE Loss (L2 norm)= 1.014E-04
# Epoch 462: MSE Loss (L2 norm)= 1.009E-04
# Epoch 463: MSE Loss (L2 norm)= 1.005E-04
# Epoch 464: MSE Loss (L2 norm)= 1.000E-04
# Epoch 465: MSE Loss (L2 norm)= 9.959E-05
# Epoch 466: MSE Loss (L2 norm)= 9.916E-05
# Epoch 467: MSE Loss (L2 norm)= 9.875E-05
# Epoch 468: MSE Loss (L2 norm)= 9.834E-05
# Epoch 469: MSE Loss (L2 norm)= 9.793E-05
# Epoch 470: MSE Loss (L2 norm)= 9.754E-05
# Epoch 471: MSE Loss (L2 norm)= 9.714E-05
# Epoch 472: MSE Loss (L2 norm)= 9.675E-05
# Epoch 473: MSE Loss (L2 norm)= 9.637E-05
# Epoch 474: MSE Loss (L2 norm)= 9.599E-05
# Epoch 475: MSE Loss (L2 norm)= 9.561E-05
# Epoch 476: MSE Loss (L2 norm)= 9.524E-05
# Epoch 477: MSE Loss (L2 norm)= 9.487E-05
# Epoch 478: MSE Loss (L2 norm)= 9.451E-05
# Epoch 479: MSE Loss (L2 norm)= 9.415E-05
# Epoch 480: MSE Loss (L2 norm)= 9.380E-05
# Epoch 481: MSE Loss (L2 norm)= 9.345E-05
# Epoch 482: MSE Loss (L2 norm)= 9.310E-05
# Epoch 483: MSE Loss (L2 norm)= 9.276E-05
# Epoch 484: MSE Loss (L2 norm)= 9.242E-05
# Epoch 485: MSE Loss (L2 norm)= 9.209E-05
# Epoch 486: MSE Loss (L2 norm)= 9.176E-05
# Epoch 487: MSE Loss (L2 norm)= 9.144E-05
# Epoch 488: MSE Loss (L2 norm)= 9.111E-05
# Epoch 489: MSE Loss (L2 norm)= 9.079E-05
# Epoch 490: MSE Loss (L2 norm)= 9.048E-05
# Epoch 491: MSE Loss (L2 norm)= 9.016E-05
# Epoch 492: MSE Loss (L2 norm)= 8.985E-05
# Epoch 493: MSE Loss (L2 norm)= 8.955E-05
# Epoch 494: MSE Loss (L2 norm)= 8.925E-05
# Epoch 495: MSE Loss (L2 norm)= 8.895E-05
# Epoch 496: MSE Loss (L2 norm)= 8.866E-05
# Epoch 497: MSE Loss (L2 norm)= 8.836E-05
# Epoch 498: MSE Loss (L2 norm)= 8.807E-05
# Epoch 499: MSE Loss (L2 norm)= 8.778E-05
# Epoch 500: MSE Loss (L2 norm)= 8.750E-05
# Epoch 501: MSE Loss (L2 norm)= 8.722E-05
# Epoch 502: MSE Loss (L2 norm)= 8.694E-05
# Epoch 503: MSE Loss (L2 norm)= 8.666E-05
# Epoch 504: MSE Loss (L2 norm)= 8.639E-05
# Epoch 505: MSE Loss (L2 norm)= 8.611E-05
# Epoch 506: MSE Loss (L2 norm)= 8.584E-05
# Epoch 507: MSE Loss (L2 norm)= 8.557E-05
# Epoch 508: MSE Loss (L2 norm)= 8.531E-05
# Epoch 509: MSE Loss (L2 norm)= 8.505E-05
# Epoch 510: MSE Loss (L2 norm)= 8.478E-05
# Epoch 511: MSE Loss (L2 norm)= 8.452E-05
# Epoch 512: MSE Loss (L2 norm)= 8.427E-05
# Epoch 513: MSE Loss (L2 norm)= 8.401E-05
# Epoch 514: MSE Loss (L2 norm)= 8.376E-05
# Epoch 515: MSE Loss (L2 norm)= 8.351E-05
# Epoch 516: MSE Loss (L2 norm)= 8.327E-05
# Epoch 517: MSE Loss (L2 norm)= 8.302E-05
# Epoch 518: MSE Loss (L2 norm)= 8.278E-05
# Epoch 519: MSE Loss (L2 norm)= 8.254E-05
# Epoch 520: MSE Loss (L2 norm)= 8.231E-05
# Epoch 521: MSE Loss (L2 norm)= 8.208E-05
# Epoch 522: MSE Loss (L2 norm)= 8.185E-05
# Epoch 523: MSE Loss (L2 norm)= 8.163E-05
# Epoch 524: MSE Loss (L2 norm)= 8.141E-05
# Epoch 525: MSE Loss (L2 norm)= 8.119E-05
# Epoch 526: MSE Loss (L2 norm)= 8.099E-05
# Epoch 527: MSE Loss (L2 norm)= 8.079E-05
# Epoch 528: MSE Loss (L2 norm)= 8.059E-05
# Epoch 529: MSE Loss (L2 norm)= 8.042E-05
# Epoch 530: MSE Loss (L2 norm)= 8.025E-05
# Epoch 531: MSE Loss (L2 norm)= 8.009E-05
# Epoch 532: MSE Loss (L2 norm)= 7.995E-05
# Epoch 533: MSE Loss (L2 norm)= 7.983E-05
# Epoch 534: MSE Loss (L2 norm)= 7.973E-05
# Epoch 535: MSE Loss (L2 norm)= 7.965E-05
# Epoch 536: MSE Loss (L2 norm)= 7.959E-05
# Epoch 537: MSE Loss (L2 norm)= 7.953E-05
# Epoch 538: MSE Loss (L2 norm)= 7.948E-05
# Epoch 539: MSE Loss (L2 norm)= 7.941E-05
# Epoch 540: MSE Loss (L2 norm)= 7.933E-05
# Epoch 541: MSE Loss (L2 norm)= 7.919E-05
# Epoch 542: MSE Loss (L2 norm)= 7.905E-05
# Epoch 543: MSE Loss (L2 norm)= 7.881E-05
# Epoch 544: MSE Loss (L2 norm)= 7.853E-05
# Epoch 545: MSE Loss (L2 norm)= 7.817E-05
# Epoch 546: MSE Loss (L2 norm)= 7.779E-05
# Epoch 547: MSE Loss (L2 norm)= 7.739E-05
# Epoch 548: MSE Loss (L2 norm)= 7.700E-05
# Epoch 549: MSE Loss (L2 norm)= 7.663E-05
# Epoch 550: MSE Loss (L2 norm)= 7.629E-05
# Epoch 551: MSE Loss (L2 norm)= 7.599E-05
# Epoch 552: MSE Loss (L2 norm)= 7.571E-05
# Epoch 553: MSE Loss (L2 norm)= 7.546E-05
# Epoch 554: MSE Loss (L2 norm)= 7.523E-05
# Epoch 555: MSE Loss (L2 norm)= 7.502E-05
# Epoch 556: MSE Loss (L2 norm)= 7.481E-05
# Epoch 557: MSE Loss (L2 norm)= 7.462E-05
# Epoch 558: MSE Loss (L2 norm)= 7.445E-05
# Epoch 559: MSE Loss (L2 norm)= 7.429E-05
# Epoch 560: MSE Loss (L2 norm)= 7.416E-05
# Epoch 561: MSE Loss (L2 norm)= 7.408E-05
# Epoch 562: MSE Loss (L2 norm)= 7.406E-05
# Epoch 563: MSE Loss (L2 norm)= 7.415E-05
# Epoch 564: MSE Loss (L2 norm)= 7.442E-05
# Epoch 565: MSE Loss (L2 norm)= 7.492E-05
# Epoch 566: MSE Loss (L2 norm)= 7.589E-05
# Epoch 567: MSE Loss (L2 norm)= 7.738E-05
# Epoch 568: MSE Loss (L2 norm)= 7.977E-05
# Epoch 569: MSE Loss (L2 norm)= 8.084E-05
# Epoch 570: MSE Loss (L2 norm)= 8.242E-05
# Epoch 571: MSE Loss (L2 norm)= 8.105E-05
# Epoch 572: MSE Loss (L2 norm)= 7.960E-05
# Epoch 573: MSE Loss (L2 norm)= 7.598E-05
# Epoch 574: MSE Loss (L2 norm)= 7.331E-05
# Epoch 575: MSE Loss (L2 norm)= 7.156E-05
# Epoch 576: MSE Loss (L2 norm)= 7.119E-05
# Epoch 577: MSE Loss (L2 norm)= 7.191E-05
# Epoch 578: MSE Loss (L2 norm)= 7.297E-05
# Epoch 579: MSE Loss (L2 norm)= 7.367E-05
# Epoch 580: MSE Loss (L2 norm)= 7.352E-05
# Epoch 581: MSE Loss (L2 norm)= 7.301E-05
# Epoch 582: MSE Loss (L2 norm)= 7.189E-05
# Epoch 583: MSE Loss (L2 norm)= 7.076E-05
# Epoch 584: MSE Loss (L2 norm)= 6.989E-05
# Epoch 585: MSE Loss (L2 norm)= 6.950E-05
# Epoch 586: MSE Loss (L2 norm)= 6.953E-05
# Epoch 587: MSE Loss (L2 norm)= 6.981E-05
# Epoch 588: MSE Loss (L2 norm)= 7.024E-05
# Epoch 589: MSE Loss (L2 norm)= 7.057E-05
# Epoch 590: MSE Loss (L2 norm)= 7.091E-05
# Epoch 591: MSE Loss (L2 norm)= 7.093E-05
# Epoch 592: MSE Loss (L2 norm)= 7.092E-05
# Epoch 593: MSE Loss (L2 norm)= 7.052E-05
# Epoch 594: MSE Loss (L2 norm)= 7.012E-05
# Epoch 595: MSE Loss (L2 norm)= 6.944E-05
# Epoch 596: MSE Loss (L2 norm)= 6.869E-05
# Epoch 597: MSE Loss (L2 norm)= 6.802E-05
# Epoch 598: MSE Loss (L2 norm)= 6.753E-05
# Epoch 599: MSE Loss (L2 norm)= 6.726E-05
# Epoch 600: MSE Loss (L2 norm)= 6.718E-05
# Epoch 601: MSE Loss (L2 norm)= 6.722E-05
# Epoch 602: MSE Loss (L2 norm)= 6.729E-05
# Epoch 603: MSE Loss (L2 norm)= 6.733E-05
# Epoch 604: MSE Loss (L2 norm)= 6.728E-05
# Epoch 605: MSE Loss (L2 norm)= 6.712E-05
# Epoch 606: MSE Loss (L2 norm)= 6.688E-05
# Epoch 607: MSE Loss (L2 norm)= 6.658E-05
# Epoch 608: MSE Loss (L2 norm)= 6.624E-05
# Epoch 609: MSE Loss (L2 norm)= 6.592E-05
# Epoch 610: MSE Loss (L2 norm)= 6.563E-05
# Epoch 611: MSE Loss (L2 norm)= 6.537E-05
# Epoch 612: MSE Loss (L2 norm)= 6.515E-05
# Epoch 613: MSE Loss (L2 norm)= 6.497E-05
# Epoch 614: MSE Loss (L2 norm)= 6.481E-05
# Epoch 615: MSE Loss (L2 norm)= 6.467E-05
# Epoch 616: MSE Loss (L2 norm)= 6.455E-05
# Epoch 617: MSE Loss (L2 norm)= 6.444E-05
# Epoch 618: MSE Loss (L2 norm)= 6.435E-05
# Epoch 619: MSE Loss (L2 norm)= 6.428E-05
# Epoch 620: MSE Loss (L2 norm)= 6.424E-05
# Epoch 621: MSE Loss (L2 norm)= 6.423E-05
# Epoch 622: MSE Loss (L2 norm)= 6.428E-05
# Epoch 623: MSE Loss (L2 norm)= 6.439E-05
# Epoch 624: MSE Loss (L2 norm)= 6.462E-05
# Epoch 625: MSE Loss (L2 norm)= 6.498E-05
# Epoch 626: MSE Loss (L2 norm)= 6.554E-05
# Epoch 627: MSE Loss (L2 norm)= 6.623E-05
# Epoch 628: MSE Loss (L2 norm)= 6.726E-05
# Epoch 629: MSE Loss (L2 norm)= 6.820E-05
# Epoch 630: MSE Loss (L2 norm)= 6.953E-05
# Epoch 631: MSE Loss (L2 norm)= 7.029E-05
# Epoch 632: MSE Loss (L2 norm)= 7.227E-05
# Epoch 633: MSE Loss (L2 norm)= 7.288E-05
# Epoch 634: MSE Loss (L2 norm)= 7.324E-05
# Epoch 635: MSE Loss (L2 norm)= 7.144E-05
# Epoch 636: MSE Loss (L2 norm)= 6.906E-05
# Epoch 637: MSE Loss (L2 norm)= 6.569E-05
# Epoch 638: MSE Loss (L2 norm)= 6.285E-05
# Epoch 639: MSE Loss (L2 norm)= 6.124E-05
# Epoch 640: MSE Loss (L2 norm)= 6.111E-05
# Epoch 641: MSE Loss (L2 norm)= 6.207E-05
# Epoch 642: MSE Loss (L2 norm)= 6.332E-05
# Epoch 643: MSE Loss (L2 norm)= 6.423E-05
# Epoch 644: MSE Loss (L2 norm)= 6.423E-05
# Epoch 645: MSE Loss (L2 norm)= 6.352E-05
# Epoch 646: MSE Loss (L2 norm)= 6.222E-05
# Epoch 647: MSE Loss (L2 norm)= 6.103E-05
# Epoch 648: MSE Loss (L2 norm)= 6.010E-05
# Epoch 649: MSE Loss (L2 norm)= 5.965E-05
# Epoch 650: MSE Loss (L2 norm)= 5.964E-05
# Epoch 651: MSE Loss (L2 norm)= 5.991E-05
# Epoch 652: MSE Loss (L2 norm)= 6.028E-05
# Epoch 653: MSE Loss (L2 norm)= 6.057E-05
# Epoch 654: MSE Loss (L2 norm)= 6.072E-05
# Epoch 655: MSE Loss (L2 norm)= 6.062E-05
# Epoch 656: MSE Loss (L2 norm)= 6.035E-05
# Epoch 657: MSE Loss (L2 norm)= 5.992E-05
# Epoch 658: MSE Loss (L2 norm)= 5.945E-05
# Epoch 659: MSE Loss (L2 norm)= 5.898E-05
# Epoch 660: MSE Loss (L2 norm)= 5.857E-05
# Epoch 661: MSE Loss (L2 norm)= 5.823E-05
# Epoch 662: MSE Loss (L2 norm)= 5.799E-05
# Epoch 663: MSE Loss (L2 norm)= 5.782E-05
# Epoch 664: MSE Loss (L2 norm)= 5.771E-05
# Epoch 665: MSE Loss (L2 norm)= 5.764E-05
# Epoch 666: MSE Loss (L2 norm)= 5.760E-05
# Epoch 667: MSE Loss (L2 norm)= 5.758E-05
# Epoch 668: MSE Loss (L2 norm)= 5.756E-05
# Epoch 669: MSE Loss (L2 norm)= 5.754E-05
# Epoch 670: MSE Loss (L2 norm)= 5.751E-05
# Epoch 671: MSE Loss (L2 norm)= 5.748E-05
# Epoch 672: MSE Loss (L2 norm)= 5.745E-05
# Epoch 673: MSE Loss (L2 norm)= 5.742E-05
# Epoch 674: MSE Loss (L2 norm)= 5.739E-05
# Epoch 675: MSE Loss (L2 norm)= 5.740E-05
# Epoch 676: MSE Loss (L2 norm)= 5.741E-05
# Epoch 677: MSE Loss (L2 norm)= 5.749E-05
# Epoch 678: MSE Loss (L2 norm)= 5.760E-05
# Epoch 679: MSE Loss (L2 norm)= 5.782E-05
# Epoch 680: MSE Loss (L2 norm)= 5.811E-05
# Epoch 681: MSE Loss (L2 norm)= 5.859E-05
# Epoch 682: MSE Loss (L2 norm)= 5.919E-05
# Epoch 683: MSE Loss (L2 norm)= 6.013E-05
# Epoch 684: MSE Loss (L2 norm)= 6.128E-05
# Epoch 685: MSE Loss (L2 norm)= 6.303E-05
# Epoch 686: MSE Loss (L2 norm)= 6.391E-05
# Epoch 687: MSE Loss (L2 norm)= 6.549E-05
# Epoch 688: MSE Loss (L2 norm)= 6.547E-05
# Epoch 689: MSE Loss (L2 norm)= 6.713E-05
# Epoch 690: MSE Loss (L2 norm)= 6.635E-05
# Epoch 691: MSE Loss (L2 norm)= 6.690E-05
# Epoch 692: MSE Loss (L2 norm)= 6.450E-05
# Epoch 693: MSE Loss (L2 norm)= 6.208E-05
# Epoch 694: MSE Loss (L2 norm)= 5.842E-05
# Epoch 695: MSE Loss (L2 norm)= 5.566E-05
# Epoch 696: MSE Loss (L2 norm)= 5.407E-05
# Epoch 697: MSE Loss (L2 norm)= 5.400E-05
# Epoch 698: MSE Loss (L2 norm)= 5.500E-05
# Epoch 699: MSE Loss (L2 norm)= 5.615E-05
# Epoch 700: MSE Loss (L2 norm)= 5.702E-05
# Epoch 701: MSE Loss (L2 norm)= 5.676E-05
# Epoch 702: MSE Loss (L2 norm)= 5.594E-05
# Epoch 703: MSE Loss (L2 norm)= 5.457E-05
# Epoch 704: MSE Loss (L2 norm)= 5.341E-05
# Epoch 705: MSE Loss (L2 norm)= 5.289E-05
# Epoch 706: MSE Loss (L2 norm)= 5.307E-05
# Epoch 707: MSE Loss (L2 norm)= 5.365E-05
# Epoch 708: MSE Loss (L2 norm)= 5.418E-05
# Epoch 709: MSE Loss (L2 norm)= 5.440E-05
# Epoch 710: MSE Loss (L2 norm)= 5.416E-05
# Epoch 711: MSE Loss (L2 norm)= 5.362E-05
# Epoch 712: MSE Loss (L2 norm)= 5.293E-05
# Epoch 713: MSE Loss (L2 norm)= 5.234E-05
# Epoch 714: MSE Loss (L2 norm)= 5.196E-05
# Epoch 715: MSE Loss (L2 norm)= 5.184E-05
# Epoch 716: MSE Loss (L2 norm)= 5.190E-05
# Epoch 717: MSE Loss (L2 norm)= 5.205E-05
# Epoch 718: MSE Loss (L2 norm)= 5.219E-05
# Epoch 719: MSE Loss (L2 norm)= 5.224E-05
# Epoch 720: MSE Loss (L2 norm)= 5.218E-05
# Epoch 721: MSE Loss (L2 norm)= 5.202E-05
# Epoch 722: MSE Loss (L2 norm)= 5.178E-05
# Epoch 723: MSE Loss (L2 norm)= 5.151E-05
# Epoch 724: MSE Loss (L2 norm)= 5.124E-05
# Epoch 725: MSE Loss (L2 norm)= 5.099E-05
# Epoch 726: MSE Loss (L2 norm)= 5.079E-05
# Epoch 727: MSE Loss (L2 norm)= 5.063E-05
# Epoch 728: MSE Loss (L2 norm)= 5.051E-05
# Epoch 729: MSE Loss (L2 norm)= 5.043E-05
# Epoch 730: MSE Loss (L2 norm)= 5.036E-05
# Epoch 731: MSE Loss (L2 norm)= 5.031E-05
# Epoch 732: MSE Loss (L2 norm)= 5.027E-05
# Epoch 733: MSE Loss (L2 norm)= 5.024E-05
# Epoch 734: MSE Loss (L2 norm)= 5.022E-05
# Epoch 735: MSE Loss (L2 norm)= 5.021E-05
# Epoch 736: MSE Loss (L2 norm)= 5.022E-05
# Epoch 737: MSE Loss (L2 norm)= 5.027E-05
# Epoch 738: MSE Loss (L2 norm)= 5.035E-05
# Epoch 739: MSE Loss (L2 norm)= 5.052E-05
# Epoch 740: MSE Loss (L2 norm)= 5.077E-05
# Epoch 741: MSE Loss (L2 norm)= 5.120E-05
# Epoch 742: MSE Loss (L2 norm)= 5.181E-05
# Epoch 743: MSE Loss (L2 norm)= 5.282E-05
# Epoch 744: MSE Loss (L2 norm)= 5.423E-05
# Epoch 745: MSE Loss (L2 norm)= 5.651E-05
# Epoch 746: MSE Loss (L2 norm)= 5.964E-05
# Epoch 747: MSE Loss (L2 norm)= 6.448E-05
# Epoch 748: MSE Loss (L2 norm)= 6.955E-05
# Epoch 749: MSE Loss (L2 norm)= 7.666E-05
# Epoch 750: MSE Loss (L2 norm)= 7.785E-05
# Epoch 751: MSE Loss (L2 norm)= 8.225E-05
# Epoch 752: MSE Loss (L2 norm)= 7.585E-05
# Epoch 753: MSE Loss (L2 norm)= 7.073E-05
# Epoch 754: MSE Loss (L2 norm)= 5.964E-05
# Epoch 755: MSE Loss (L2 norm)= 5.153E-05
# Epoch 756: MSE Loss (L2 norm)= 4.809E-05
# Epoch 757: MSE Loss (L2 norm)= 5.030E-05
# Epoch 758: MSE Loss (L2 norm)= 5.537E-05
# Epoch 759: MSE Loss (L2 norm)= 5.850E-05
# Epoch 760: MSE Loss (L2 norm)= 5.987E-05
# Epoch 761: MSE Loss (L2 norm)= 5.570E-05
# Epoch 762: MSE Loss (L2 norm)= 5.151E-05
# Epoch 763: MSE Loss (L2 norm)= 4.807E-05
# Epoch 764: MSE Loss (L2 norm)= 4.770E-05
# Epoch 765: MSE Loss (L2 norm)= 4.969E-05
# Epoch 766: MSE Loss (L2 norm)= 5.168E-05
# Epoch 767: MSE Loss (L2 norm)= 5.274E-05
# Epoch 768: MSE Loss (L2 norm)= 5.137E-05
# Epoch 769: MSE Loss (L2 norm)= 4.937E-05
# Epoch 770: MSE Loss (L2 norm)= 4.753E-05
# Epoch 771: MSE Loss (L2 norm)= 4.678E-05
# Epoch 772: MSE Loss (L2 norm)= 4.714E-05
# Epoch 773: MSE Loss (L2 norm)= 4.806E-05
# Epoch 774: MSE Loss (L2 norm)= 4.895E-05
# Epoch 775: MSE Loss (L2 norm)= 4.912E-05
# Epoch 776: MSE Loss (L2 norm)= 4.871E-05
# Epoch 777: MSE Loss (L2 norm)= 4.783E-05
# Epoch 778: MSE Loss (L2 norm)= 4.692E-05
# Epoch 779: MSE Loss (L2 norm)= 4.627E-05
# Epoch 780: MSE Loss (L2 norm)= 4.602E-05
# Epoch 781: MSE Loss (L2 norm)= 4.616E-05
# Epoch 782: MSE Loss (L2 norm)= 4.649E-05
# Epoch 783: MSE Loss (L2 norm)= 4.679E-05
# Epoch 784: MSE Loss (L2 norm)= 4.691E-05
# Epoch 785: MSE Loss (L2 norm)= 4.680E-05
# Epoch 786: MSE Loss (L2 norm)= 4.648E-05
# Epoch 787: MSE Loss (L2 norm)= 4.611E-05
# Epoch 788: MSE Loss (L2 norm)= 4.573E-05
# Epoch 789: MSE Loss (L2 norm)= 4.543E-05
# Epoch 790: MSE Loss (L2 norm)= 4.524E-05
# Epoch 791: MSE Loss (L2 norm)= 4.514E-05
# Epoch 792: MSE Loss (L2 norm)= 4.512E-05
# Epoch 793: MSE Loss (L2 norm)= 4.514E-05
# Epoch 794: MSE Loss (L2 norm)= 4.519E-05
# Epoch 795: MSE Loss (L2 norm)= 4.523E-05
# Epoch 796: MSE Loss (L2 norm)= 4.526E-05
# Epoch 797: MSE Loss (L2 norm)= 4.527E-05
# Epoch 798: MSE Loss (L2 norm)= 4.527E-05
# Epoch 799: MSE Loss (L2 norm)= 4.526E-05
# Epoch 800: MSE Loss (L2 norm)= 4.526E-05
# Epoch 801: MSE Loss (L2 norm)= 4.525E-05
# Epoch 802: MSE Loss (L2 norm)= 4.528E-05
# Epoch 803: MSE Loss (L2 norm)= 4.531E-05
# Epoch 804: MSE Loss (L2 norm)= 4.541E-05
# Epoch 805: MSE Loss (L2 norm)= 4.556E-05
# Epoch 806: MSE Loss (L2 norm)= 4.583E-05
# Epoch 807: MSE Loss (L2 norm)= 4.621E-05
# Epoch 808: MSE Loss (L2 norm)= 4.683E-05
# Epoch 809: MSE Loss (L2 norm)= 4.767E-05
# Epoch 810: MSE Loss (L2 norm)= 4.902E-05
# Epoch 811: MSE Loss (L2 norm)= 5.086E-05
# Epoch 812: MSE Loss (L2 norm)= 5.375E-05
# Epoch 813: MSE Loss (L2 norm)= 5.596E-05
# Epoch 814: MSE Loss (L2 norm)= 5.945E-05
# Epoch 815: MSE Loss (L2 norm)= 6.095E-05
# Epoch 816: MSE Loss (L2 norm)= 6.431E-05
# Epoch 817: MSE Loss (L2 norm)= 6.414E-05
# Epoch 818: MSE Loss (L2 norm)= 6.494E-05
# Epoch 819: MSE Loss (L2 norm)= 6.085E-05
# Epoch 820: MSE Loss (L2 norm)= 5.610E-05
# Epoch 821: MSE Loss (L2 norm)= 4.954E-05
# Epoch 822: MSE Loss (L2 norm)= 4.451E-05
# Epoch 823: MSE Loss (L2 norm)= 4.303E-05
# Epoch 824: MSE Loss (L2 norm)= 4.496E-05
# Epoch 825: MSE Loss (L2 norm)= 4.812E-05
# Epoch 826: MSE Loss (L2 norm)= 4.987E-05
# Epoch 827: MSE Loss (L2 norm)= 4.931E-05
# Epoch 828: MSE Loss (L2 norm)= 4.664E-05
# Epoch 829: MSE Loss (L2 norm)= 4.391E-05
# Epoch 830: MSE Loss (L2 norm)= 4.246E-05
# Epoch 831: MSE Loss (L2 norm)= 4.279E-05
# Epoch 832: MSE Loss (L2 norm)= 4.436E-05
# Epoch 833: MSE Loss (L2 norm)= 4.594E-05
# Epoch 834: MSE Loss (L2 norm)= 4.727E-05
# Epoch 835: MSE Loss (L2 norm)= 4.717E-05
# Epoch 836: MSE Loss (L2 norm)= 4.656E-05
# Epoch 837: MSE Loss (L2 norm)= 4.494E-05
# Epoch 838: MSE Loss (L2 norm)= 4.348E-05
# Epoch 839: MSE Loss (L2 norm)= 4.224E-05
# Epoch 840: MSE Loss (L2 norm)= 4.173E-05
# Epoch 841: MSE Loss (L2 norm)= 4.189E-05
# Epoch 842: MSE Loss (L2 norm)= 4.242E-05
# Epoch 843: MSE Loss (L2 norm)= 4.289E-05
# Epoch 844: MSE Loss (L2 norm)= 4.298E-05
# Epoch 845: MSE Loss (L2 norm)= 4.268E-05
# Epoch 846: MSE Loss (L2 norm)= 4.213E-05
# Epoch 847: MSE Loss (L2 norm)= 4.158E-05
# Epoch 848: MSE Loss (L2 norm)= 4.122E-05
# Epoch 849: MSE Loss (L2 norm)= 4.112E-05
# Epoch 850: MSE Loss (L2 norm)= 4.122E-05
# Epoch 851: MSE Loss (L2 norm)= 4.140E-05
# Epoch 852: MSE Loss (L2 norm)= 4.153E-05
# Epoch 853: MSE Loss (L2 norm)= 4.155E-05
# Epoch 854: MSE Loss (L2 norm)= 4.155E-05
# Epoch 855: MSE Loss (L2 norm)= 4.143E-05
# Epoch 856: MSE Loss (L2 norm)= 4.132E-05
# Epoch 857: MSE Loss (L2 norm)= 4.113E-05
# Epoch 858: MSE Loss (L2 norm)= 4.098E-05
# Epoch 859: MSE Loss (L2 norm)= 4.079E-05
# Epoch 860: MSE Loss (L2 norm)= 4.064E-05
# Epoch 861: MSE Loss (L2 norm)= 4.050E-05
# Epoch 862: MSE Loss (L2 norm)= 4.036E-05
# Epoch 863: MSE Loss (L2 norm)= 4.024E-05
# Epoch 864: MSE Loss (L2 norm)= 4.013E-05
# Epoch 865: MSE Loss (L2 norm)= 4.004E-05
# Epoch 866: MSE Loss (L2 norm)= 3.996E-05
# Epoch 867: MSE Loss (L2 norm)= 3.989E-05
# Epoch 868: MSE Loss (L2 norm)= 3.982E-05
# Epoch 869: MSE Loss (L2 norm)= 3.976E-05
# Epoch 870: MSE Loss (L2 norm)= 3.971E-05
# Epoch 871: MSE Loss (L2 norm)= 3.966E-05
# Epoch 872: MSE Loss (L2 norm)= 3.961E-05
# Epoch 873: MSE Loss (L2 norm)= 3.958E-05
# Epoch 874: MSE Loss (L2 norm)= 3.955E-05
# Epoch 875: MSE Loss (L2 norm)= 3.954E-05
# Epoch 876: MSE Loss (L2 norm)= 3.957E-05
# Epoch 877: MSE Loss (L2 norm)= 3.968E-05
# Epoch 878: MSE Loss (L2 norm)= 3.990E-05
# Epoch 879: MSE Loss (L2 norm)= 4.047E-05
# Epoch 880: MSE Loss (L2 norm)= 4.148E-05
# Epoch 881: MSE Loss (L2 norm)= 4.380E-05
# Epoch 882: MSE Loss (L2 norm)= 4.782E-05
# Epoch 883: MSE Loss (L2 norm)= 5.725E-05
# Epoch 884: MSE Loss (L2 norm)= 7.025E-05
# Epoch 885: MSE Loss (L2 norm)= 1.032E-04
# Epoch 886: MSE Loss (L2 norm)= 1.309E-04
# Epoch 887: MSE Loss (L2 norm)= 2.066E-04
# Epoch 888: MSE Loss (L2 norm)= 1.909E-04
# Epoch 889: MSE Loss (L2 norm)= 1.925E-04
# Epoch 890: MSE Loss (L2 norm)= 8.056E-05
# Epoch 891: MSE Loss (L2 norm)= 4.213E-05
# Epoch 892: MSE Loss (L2 norm)= 8.322E-05
# Epoch 893: MSE Loss (L2 norm)= 1.191E-04
# Epoch 894: MSE Loss (L2 norm)= 1.211E-04
# Epoch 895: MSE Loss (L2 norm)= 5.609E-05
# Epoch 896: MSE Loss (L2 norm)= 4.601E-05
# Epoch 897: MSE Loss (L2 norm)= 8.551E-05
# Epoch 898: MSE Loss (L2 norm)= 8.561E-05
# Epoch 899: MSE Loss (L2 norm)= 5.917E-05
# Epoch 900: MSE Loss (L2 norm)= 4.061E-05
# Epoch 901: MSE Loss (L2 norm)= 6.109E-05
# Epoch 902: MSE Loss (L2 norm)= 7.698E-05
# Epoch 903: MSE Loss (L2 norm)= 5.342E-05
# Epoch 904: MSE Loss (L2 norm)= 3.905E-05
# Epoch 905: MSE Loss (L2 norm)= 5.291E-05
# Epoch 906: MSE Loss (L2 norm)= 6.180E-05
# Epoch 907: MSE Loss (L2 norm)= 5.137E-05
# Epoch 908: MSE Loss (L2 norm)= 3.889E-05
# Epoch 909: MSE Loss (L2 norm)= 4.494E-05
# Epoch 910: MSE Loss (L2 norm)= 5.492E-05
# Epoch 911: MSE Loss (L2 norm)= 4.747E-05
# Epoch 912: MSE Loss (L2 norm)= 3.901E-05
# Epoch 913: MSE Loss (L2 norm)= 4.117E-05
# Epoch 914: MSE Loss (L2 norm)= 4.685E-05
# Epoch 915: MSE Loss (L2 norm)= 4.619E-05
# Epoch 916: MSE Loss (L2 norm)= 3.936E-05
# Epoch 917: MSE Loss (L2 norm)= 3.885E-05
# Epoch 918: MSE Loss (L2 norm)= 4.295E-05
# Epoch 919: MSE Loss (L2 norm)= 4.271E-05
# Epoch 920: MSE Loss (L2 norm)= 3.868E-05
# Epoch 921: MSE Loss (L2 norm)= 3.802E-05
# Epoch 922: MSE Loss (L2 norm)= 4.069E-05
# Epoch 923: MSE Loss (L2 norm)= 4.088E-05
# Epoch 924: MSE Loss (L2 norm)= 3.824E-05
# Epoch 925: MSE Loss (L2 norm)= 3.743E-05
# Epoch 926: MSE Loss (L2 norm)= 3.917E-05
# Epoch 927: MSE Loss (L2 norm)= 3.957E-05
# Epoch 928: MSE Loss (L2 norm)= 3.791E-05
# Epoch 929: MSE Loss (L2 norm)= 3.700E-05
# Epoch 930: MSE Loss (L2 norm)= 3.790E-05
# Epoch 931: MSE Loss (L2 norm)= 3.863E-05
# Epoch 932: MSE Loss (L2 norm)= 3.777E-05
# Epoch 933: MSE Loss (L2 norm)= 3.680E-05
# Epoch 934: MSE Loss (L2 norm)= 3.697E-05
# Epoch 935: MSE Loss (L2 norm)= 3.762E-05
# Epoch 936: MSE Loss (L2 norm)= 3.751E-05
# Epoch 937: MSE Loss (L2 norm)= 3.675E-05
# Epoch 938: MSE Loss (L2 norm)= 3.647E-05
# Epoch 939: MSE Loss (L2 norm)= 3.682E-05
# Epoch 940: MSE Loss (L2 norm)= 3.701E-05
# Epoch 941: MSE Loss (L2 norm)= 3.664E-05
# Epoch 942: MSE Loss (L2 norm)= 3.625E-05
# Epoch 943: MSE Loss (L2 norm)= 3.629E-05
# Epoch 944: MSE Loss (L2 norm)= 3.652E-05
# Epoch 945: MSE Loss (L2 norm)= 3.643E-05
# Epoch 946: MSE Loss (L2 norm)= 3.612E-05
# Epoch 947: MSE Loss (L2 norm)= 3.597E-05
# Epoch 948: MSE Loss (L2 norm)= 3.606E-05
# Epoch 949: MSE Loss (L2 norm)= 3.613E-05
# Epoch 950: MSE Loss (L2 norm)= 3.599E-05
# Epoch 951: MSE Loss (L2 norm)= 3.579E-05
# Epoch 952: MSE Loss (L2 norm)= 3.573E-05
# Epoch 953: MSE Loss (L2 norm)= 3.578E-05
# Epoch 954: MSE Loss (L2 norm)= 3.578E-05
# Epoch 955: MSE Loss (L2 norm)= 3.566E-05
# Epoch 956: MSE Loss (L2 norm)= 3.553E-05
# Epoch 957: MSE Loss (L2 norm)= 3.548E-05
# Epoch 958: MSE Loss (L2 norm)= 3.550E-05
# Epoch 959: MSE Loss (L2 norm)= 3.547E-05
# Epoch 960: MSE Loss (L2 norm)= 3.539E-05
# Epoch 961: MSE Loss (L2 norm)= 3.529E-05
# Epoch 962: MSE Loss (L2 norm)= 3.524E-05
# Epoch 963: MSE Loss (L2 norm)= 3.522E-05
# Epoch 964: MSE Loss (L2 norm)= 3.520E-05
# Epoch 965: MSE Loss (L2 norm)= 3.514E-05
# Epoch 966: MSE Loss (L2 norm)= 3.506E-05
# Epoch 967: MSE Loss (L2 norm)= 3.500E-05
# Epoch 968: MSE Loss (L2 norm)= 3.497E-05
# Epoch 969: MSE Loss (L2 norm)= 3.494E-05
# Epoch 970: MSE Loss (L2 norm)= 3.490E-05
# Epoch 971: MSE Loss (L2 norm)= 3.483E-05
# Epoch 972: MSE Loss (L2 norm)= 3.477E-05
# Epoch 973: MSE Loss (L2 norm)= 3.473E-05
# Epoch 974: MSE Loss (L2 norm)= 3.470E-05
# Epoch 975: MSE Loss (L2 norm)= 3.466E-05
# Epoch 976: MSE Loss (L2 norm)= 3.461E-05
# Epoch 977: MSE Loss (L2 norm)= 3.456E-05
# Epoch 978: MSE Loss (L2 norm)= 3.451E-05
# Epoch 979: MSE Loss (L2 norm)= 3.447E-05
# Epoch 980: MSE Loss (L2 norm)= 3.443E-05
# Epoch 981: MSE Loss (L2 norm)= 3.439E-05
# Epoch 982: MSE Loss (L2 norm)= 3.434E-05
# Epoch 983: MSE Loss (L2 norm)= 3.430E-05
# Epoch 984: MSE Loss (L2 norm)= 3.425E-05
# Epoch 985: MSE Loss (L2 norm)= 3.421E-05
# Epoch 986: MSE Loss (L2 norm)= 3.417E-05
# Epoch 987: MSE Loss (L2 norm)= 3.413E-05
# Epoch 988: MSE Loss (L2 norm)= 3.409E-05
# Epoch 989: MSE Loss (L2 norm)= 3.404E-05
# Epoch 990: MSE Loss (L2 norm)= 3.400E-05
# Epoch 991: MSE Loss (L2 norm)= 3.396E-05
# Epoch 992: MSE Loss (L2 norm)= 3.392E-05
# Epoch 993: MSE Loss (L2 norm)= 3.388E-05
# Epoch 994: MSE Loss (L2 norm)= 3.384E-05
# Epoch 995: MSE Loss (L2 norm)= 3.379E-05
# Epoch 996: MSE Loss (L2 norm)= 3.375E-05
# Epoch 997: MSE Loss (L2 norm)= 3.371E-05
# Epoch 998: MSE Loss (L2 norm)= 3.367E-05
# Epoch 999: MSE Loss (L2 norm)= 3.363E-05

# %%
my_neural_lv = neural_LV()
my_neural_lv.load_state_dict(torch.load("./models_weights/my_lv_neural_trained.eee"))
# Out:
# <All keys matched successfully>

# %%
# What if we trained SINDy without UDE-enhanched derivatives

sol = solve_ivp(lotka_volterra, t_span = [0, 20], t_eval=np.arange(0, 20, 0.01), args= (alpha, delta, beta, gamma), y0 = x0, rtol=1e-9, atol=1e-9)
data = sol.y

T = sol.t
X = data[0]
Y = data[1]

T_train_ps = T[:300:10]
X_train_ps = X[:300:10]
Y_train_ps = Y[:300:10]

model = ps.SINDy(
    feature_library=ps.PolynomialLibrary(10, include_interaction=True, include_bias=False),
    optimizer=ps.STLSQ()
)

model.fit(
    np.stack((X_train_ps, Y_train_ps), axis=-1),
    t = T_train_ps,
    # x_dot=X_dot,
    feature_names=['x','y']
        )

model.print()

# Even by manipulating the STLSQ coefficient we won't be able to get rid of the quadratic and cubic term of the unneccessary coefficients
# Out:
# (x)' =  1.248 x +  0.124 x^2 + -0.885 x y + -0.066 x^3
# (y)' = -1.800 y +  0.787 x y

# %%
# Train SINDy with the known derivatives now!

pred_new = odeint(my_lv, torch.tensor(x0, dtype=torch.float32), teval:=torch.arange(0, 3, 0.001))
pred_new_np = pred_new.detach().numpy()

T_train_ps = teval.detach().numpy()
X_train_ps = pred_new_np[:, 0]
Y_train_ps = pred_new_np[:, 1]

model = ps.SINDy(
    feature_library=ps.PolynomialLibrary(10, include_interaction=True, include_bias=False),
    optimizer=ps.STLSQ(0.3)
)

X_dot = np.zeros((T_train_ps.shape[0], 2))

for i,(t,x, y) in enumerate(zip(T_train_ps, X_train_ps, Y_train_ps)):
    X_dot[i, :] = my_lv(
        torch.tensor([t], dtype=torch.float32),
        torch.tensor([x, y], dtype=torch.float32)
    ).detach().numpy()

model.fit(
    np.stack((X_train_ps, Y_train_ps), axis=-1),
    t = T_train_ps,
    x_dot=X_dot,
    feature_names=['x','y']
        )

model.print()
# Out:
# (x)' =  1.064 x + -0.791 x y
# (y)' = -1.949 y +  1.350 x y

# %%
# do the same thing with NDE
pred_new = odeint(my_neural_lv, torch.tensor(x0, dtype=torch.float32), teval:=torch.arange(0, 3, 0.001))
pred_new_np = pred_new.detach().numpy()

T_train_ps = teval.detach().numpy()
X_train_ps = pred_new_np[:, 0]
Y_train_ps = pred_new_np[:, 1]

model = ps.SINDy(
    feature_library=ps.PolynomialLibrary(10, include_interaction=True, include_bias=False),
    optimizer=ps.STLSQ()
)

X_dot = np.zeros((T_train_ps.shape[0], 2))

for i,(t,x, y) in enumerate(zip(T_train_ps, X_train_ps, Y_train_ps)):
    X_dot[i, :] = my_lv(
        torch.tensor([t], dtype=torch.float32),
        torch.tensor([x, y], dtype=torch.float32)
    ).detach().numpy()

model.fit(
    np.stack((X_train_ps, Y_train_ps), axis=-1),
    t = T_train_ps,
    x_dot=X_dot,
    feature_names=['x','y']
        )

model.print()
# Out:
# (x)' =  2.625 x + -0.306 y + -3.793 x^2 +  2.656 x^3 + -0.429 x^5
# (y)' = -1.710 y +  0.279 x^2 +  0.491 x y

# %%
torch.save(my_lv.state_dict(), "./my_lv_trained.eee")
torch.save(my_neural_lv.state_dict(), "./my_lv_neural_trained.eee")

# to load: my_lv.load_state_dict(torch.load("..."))

# %%
# post structure parameter estimation to improve our obtained parameters

# basically just optimize the deduced functional form into what we know!

from scipy.optimize import minimize

def identified_lv(t, vars, alpha, beta, gamma, delta,):
    x, y = vars
    return np.array([
        alpha*x - beta*x*y,
        gamma*x*y - delta*y
    ])

# calculate loss to minimize
def loss_fn(params):
    alpha, beta, gamma, delta = params
    
    # solve the current lv
    sol = solve_ivp(
        identified_lv, 
        t_span=[T_train[0], T_train[-1]], 
        t_eval=T_train,
        args=(alpha, beta, gamma, delta),
        y0=x0,
        rtol=1e-9, atol=1e-9
    )

    pred_x = sol.y[0]
    pred_y = sol.y[1]
    
    error = np.sum((pred_x - X_train)**2) + np.sum((pred_y - Y_train)**2)
    return error

# optimize with initial guess from before!
x0_params = [1.254, 0.834, 0.636, 1.744]

result = minimize(loss_fn, x0_params)

print(result.x)
# Out:
# [1.30000148 0.90000097 0.80007929 1.8000203 ]

# %%
# plot my_lv.net(...)[0] vs -0.9xy on 3D (and on training data)

# %%
x_min, x_max = X_train.min() - 0.5, X_train.max() + 0.5
y_min, y_max = Y_train.min() - 0.5, Y_train.max() + 0.5

x = np.linspace(x_min, x_max, 50)
y = np.linspace(y_min, y_max, 50)
X, Y = np.meshgrid(x, y)

# Feed grid through NN
punti_input = np.stack([X.ravel(), Y.ravel()], axis=-1)
input_tensor = torch.tensor(punti_input, dtype=torch.float32)

with torch.no_grad():
    z_pred = my_lv.net(input_tensor)[:, 0]  # Take first output
    Z_nn = z_pred.reshape(X.shape).numpy()
    z_ude_pred = my_neural_lv(0, input_tensor)[:, 0]
    Z_ude_nn = - z_ude_pred.reshape(X.shape).numpy() + alpha * X # transformation into what should be the beta * x * y term

# True function: -beta*x*y (where beta=0.9)
Z_true = 0.9 * X * Y

fig = plt.figure(figsize=(14, 5))

# Plot UDE
ax1 = fig.add_subplot(131, projection='3d')
ax1.plot_surface(X, Y, Z_nn, cmap='magma', edgecolor='none')
ax1.set_title('Learned term (UDE)')

# Plot NDE 
ax2 = fig.add_subplot(132, projection='3d')
ax2.plot_surface(X, Y, Z_ude_nn, cmap='magma', edgecolor='none')
ax2.set_title('Learned term (NDE)')

# Plot NDE 
ax2 = fig.add_subplot(133, projection='3d')
ax2.plot_surface(X, Y, Z_true, cmap='magma', edgecolor='none')
ax2.set_title('True: 0.9·xy')


plt.tight_layout()
plt.show()

# %%
# Make plots
T_train = T[:300:1]
X_train = X[:300:1]
Y_train = Y[:300:1]


X_pts = X_train
Y_pts = Y_train

punti_input = np.stack([X_pts, Y_pts], axis=-1)
input_tensor = torch.tensor(punti_input, dtype=torch.float32)

with torch.no_grad():
    z_pred = my_lv.net(input_tensor).squeeze()
    Z_nn = z_pred.numpy()[:, 0]

    z_ude_pred = my_neural_lv(0, input_tensor)[:, 0]
    Z_ude_nn = -z_ude_pred.numpy() + 2 * X_pts   # extrapolate dynamics by applying some ad-hoc transformations

# True function
Z_true = beta * X_pts * Y_pts

fig = plt.figure(figsize=(14, 5))

# Plot UDE
ax1 = fig.add_subplot(131, projection='3d')
ax1.plot(X_pts, Y_pts, Z_nn)
ax1.set_title('Learned term (UDE)')
ax1.set_xlabel('X')
ax1.set_ylabel('Y')
ax1.set_zlabel('Z')

# Plot NDE
ax2 = fig.add_subplot(132, projection='3d')
ax2.plot(X_pts, Y_pts, Z_ude_nn)
ax2.set_title('Learned term (NDE)')
ax2.set_xlabel('X')
ax2.set_ylabel('Y')
ax2.set_zlabel('Z')

# Plot true
ax3 = fig.add_subplot(133, projection='3d')
ax3.plot(X_pts, Y_pts, Z_true)
ax3.set_title('True: beta * xy')
ax3.set_xlabel('X')
ax3.set_ylabel('Y')
ax3.set_zlabel('Z')

plt.tight_layout()
plt.show()

# %%
fig = plt.figure(figsize=(5, 5))
ax = fig.add_subplot(111, projection='3d')

ax.plot(X_pts, Y_pts, Z_nn, label='UDE')
ax.plot(X_pts, Y_pts, Z_ude_nn, label='NDE')
ax.plot(X_pts, Y_pts, Z_true, "--", label='True: beta(xy)')

ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
ax.view_init(elev=25, azim=-60)
ax.legend()

plt.title("Learned dynamics: side by side")
plt.show()

# %% [markdown]
# # References
#
# [1] C. Rackauckas et al., ‘Universal Differential Equations for Scientific Machine Learning’, Aug. 31, 2020, In Review. doi: 10.21203/rs.3.rs-55125/v1.
