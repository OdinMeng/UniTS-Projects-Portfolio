# %% [markdown]
# # Neuronal Models and Application of UDEs to it

# %% [markdown]
# ## Intro
# [1] In neurosciences, there are two main ways (three, actually, but we will consider only these two blablabla) to model a neuron:
# 1. *Rate models*, we let $r$ describe a unit's activity and it follows a differential equation
# 2. *Spike models*, we describe each neuron considering more dimensions for each unit, such as the membrane dynamics, the geometry of the neuron (compartments), et cetera...
#
# We will mainly focus on the first case in these notebooks.
#
# A first example of the first case is as follows:
# $$
# \tau \dot r = -r + \varphi(I_{\text{ext} }+Jr)
# $$
# Where $\varphi$ is some sort of transfer function of neurons, and it can take many forms (for example, threshold-linear, sigmoidal, et cetera...); $J$ describes the strengh of the intra-population connections: if $<0$, the neuron is said to be inhibitory, otherwise it is said to be excitatory.
#
# We can extend this into a network of neurons in two ways:
#
# The first one is to introduce a continuous variable $x$ which denotes some sort of location for the neuron. In this case we have the partial integro-differential equation (this is also known as the continuum approximation):
#
# $$
# \tau \partial_t [r(x)] = -r(x) + \varphi \left(I_{\text{ext} }(x,t) + \int_\Omega J(x,y)r(y)\text{ d}y \right)
# $$
#
# One particular choice of $x$ is to model it as some sort of angle $\theta \in [-\pi, \pi]$, obtaining the so-called ring-model:
#
#
# $$
# \tau \partial_t [r(\theta, t)] = -r(\theta) + \varphi \left(I_{\text{ext} }(\theta,t) + \int_\pi^\pi J(\theta,\theta')r(\theta', t)\text{ d}\theta' \right)
# $$
#
# Otherwise it can be formulated in a "discrete" fashion, as in [2]:
#
# $$
# \tau \dot r_k = -r_k + \varphi\left(\sum_n w_{nk} r_n + h_k\right)
# $$
#
# (TO DO: approfondire bene il discorso leggendo l'intero capitolo, potenziale collegamento con lotka-volterra per fare una transizione fluida nella tesi)
#
# [1] the review paper
# [2] the neural field theory book
#
# We will first model the basic neuron model and simulate it, then attempt to use UDEs to infer the transfer function (and possibly the parameter J as well), then we will move onto discrete neuron networks.

# %% [markdown]
# ## Part 1: Firing Rate Model
# In the first part, we will focus on the *fire rate model* of a single neuron. That is, the model of the following type:
# $$
# \tau \dot r = -r + \varphi(I_{\text{ext} }+Jr)
# $$
#
# To simplify, we will assume for the adimensionalized case $\tau = 1$.
#
# In the following examples, we will define $\varphi$ as the threshold function, that is
# $$
# \varphi_T(I) := \max\{0, I-T\}
# $$
# And $I_{\text{ext}}$ can be modelled either as a constant or a time-valued function.
#
# We will apply UDEs in three cases:
# 1. Learning the external impulse function $I(t)$, with the choice of $I(t)$ being the gaussian peak centered at $\hat t$ with variance $\sigma$, defined as
# $$
# I(t, \hat t, \sigma):=2e^{-\frac{(t-\hat t)^2}{2\sigma^2}}
# $$
# The UDE to be trained is defined as follows:
# $$
# \dot r = -r + \varphi(\texttt{NN}(t) + Jr)
# $$
#
# 2. Learning the activation function, with it being the threshold function and having a constant impulse function. The UDE in this case is
# $$
# \dot r = -r + \texttt{NN}(I_\text{ext} + Jr)
# $$
#
# 3. Both of the two cases above combined, so our UDE model will look like as follows:
# $$
# \dot r = -r + \texttt{NN}_1(\texttt{NN}_2(t) + Jr)
# $$

# %%
import numpy as np 
from scipy.integrate import solve_ivp
import matplotlib.pyplot as plt
import torch 
from torch import nn, optim
from torchdiffeq import odeint

# %%
def firing_rate_threshold(t, data, T, I_ext, J):
    x = data[0]
    r_max = 3
    activation = r_max / (1+np.exp(-1*(I_ext + J*x - T)))
    return [-x + activation]

# %%
T_max = 10

sol = solve_ivp(
    firing_rate_threshold, 
    [0, T_max], (0.1,), args=(1.0, 2, 1), t_eval=np.arange(0, T_max, 0.1),
    rtol = 1e-8, atol=1e-8)

# %%
plt.plot(np.arange(0, T_max, 0.1), sol.y[0])

plt.show()

# %% [markdown]
# ### Experiment 1: Only Impulse

# %%
def firing_rate_threshold(t, data, T, I_ext, J):
    x = data[0]
    activation = np.maximum(0, I_ext(t)+J*x-T)
    return [-x + activation]

def I(t, t_peak, sigma):
    return 2.0 * np.exp(-((t - t_peak)**2) / (2 * sigma**2)) 
    
T_max = 20

sol = solve_ivp(
    firing_rate_threshold, 
    [0, T_max], (1.,), args=(1, lambda t: I(t, 2.5, 0.5), 1), t_eval=np.arange(0, T_max, 0.1),
    rtol = 1e-8, atol=1e-8)

fig, axes = plt.subplots(1, 2, figsize=(12, 3))

plt.sca(axes[1])

plt.plot(sol.t, sol.y[0])

X_train = sol.y[0][::5]
T_train = sol.t[::5]

plt.scatter(T_train, X_train)

plt.xlabel("$t$")
plt.ylabel("$r(t)$")

plt.sca(axes[0])

t_true = np.linspace(0, T_train[-1], 200)
I_true = np.array([I(t, 2.5, 0.5) for t in t_true])
plt.plot(t_true, I_true, 'r--', linewidth=2, label='True I(t)')
plt.xlabel("$t$")
plt.ylabel("$I(t)$")

plt.show()

# %%
# hmmm... i can try to make an UDE which learns the impulse!!!!
class my_universal_neuron(nn.Module):
    def __init__(self, transfer, threshold, strength):
        super().__init__()

        self.transfer = transfer # N.B. TRANSFER HAS TO WORK ON TENSORS!!!!!!!!
        self.register_buffer("threshold", torch.as_tensor(threshold, dtype=torch.float32))
        self.register_buffer("strength", torch.as_tensor(strength, dtype=torch.float32))

        self.net = nn.Sequential(
            nn.Linear(1, 16),
            nn.Tanh(),
            nn.Linear(16, 32),
            nn.Tanh(),
            nn.Linear(32, 32),
            nn.Tanh(),
            nn.Linear(32, 32),
            nn.Tanh(),
            nn.Linear(32, 16),
            nn.Tanh(),
            nn.Linear(16, 1)
        )


    def forward(self, t, x):
        external_impulse = self.net(t.reshape(1,1))

        return -x + self.transfer(external_impulse + self.strength * x, self.threshold)
    
def transfer_threshold(I, T):
    return torch.maximum(
        torch.tensor([0.], requires_grad=True),
        I-T
    )

def fake_threshold(I, T):
    return torch.nn.functional.softplus(1000 * (I - T)) / 1000

# %%
# Problem: the actual transfer threshold's derivative behaves badly, as it vanishes for values under the threshold. (and as a matter of fact is not differentiable in some points) 
# So we replaced by its "soft" surrogate, known also as the "softmax" function (in this case we use the softplus function)
# To give an idea we will plot the two transfer functions:

x_transfer = np.arange(0, 2, 0.01)
y_threshold = np.maximum(0, x_transfer-1)
y_fake_threshold1 = np.log(1+ np.exp( (x_transfer-1)))
y_fake_threshold2 = np.log(1+ np.exp( 2* (x_transfer-1))) / 2
y_fake_threshold3 = np.log(1+ np.exp( 4*(x_transfer-1))) / 4
y_fake_threshold4 = np.log(1+ np.exp( 8*(x_transfer-1))) / 8

fig, ax = plt.subplots()

ax.plot(x_transfer, y_threshold, 'b', label="Real threshold")
ax.plot(x_transfer, y_fake_threshold1, 'r--', label="Fake threshold (beta=1,2,4,8 from top to bottom)")
ax.plot(x_transfer, y_fake_threshold2, 'r--')
ax.plot(x_transfer, y_fake_threshold3, 'r--')
ax.plot(x_transfer, y_fake_threshold4, 'r--')

plt.legend()
plt.title("Threshold activation surrogate: an idea of convergence")

plt.show()

# %%
from tqdm import tqdm 

my_monkey = my_universal_neuron(
    fake_threshold, torch.tensor([1.]), torch.tensor([1.])
)

lr = 0.003
optimizer = optim.Adam(my_monkey.parameters(), lr=lr)

n_epochs = 1000
rtol = 1e-7

t_train_torch = torch.tensor(T_train)

for EPOCH in (range(n_epochs)):
    optimizer.zero_grad()
    my_monkey.zero_grad()
    
    # forward solution
    x_pred = odeint(my_monkey, 
                    torch.tensor([1.], requires_grad=False),
                    t_train_torch,
                    rtol=rtol
                    )
    
    # Compute loss at training points
    loss = torch.tensor(0., requires_grad=True)
    for i, (t, x_true) in enumerate(zip(T_train, X_train)):
        loss = loss + (x_pred[i] - x_true) ** 2
    
    loss = loss / len(T_train)
    
    # Backpropagate
    loss.backward()
    optimizer.step()
    
    print(f"Epoch {EPOCH}: MSE Loss = {loss.item():.4e}")
# Out:
# Epoch 0: MSE Loss = 4.0231e-02
# Epoch 1: MSE Loss = 4.0184e-02
# Epoch 2: MSE Loss = 4.0103e-02
# Epoch 3: MSE Loss = 3.9977e-02
# Epoch 4: MSE Loss = 3.9804e-02
# Epoch 5: MSE Loss = 3.9584e-02
# Epoch 6: MSE Loss = 3.9423e-02
# Epoch 7: MSE Loss = 3.9402e-02
# Epoch 8: MSE Loss = 3.7231e-02
# Epoch 9: MSE Loss = 2.8654e-02
# Epoch 10: MSE Loss = 5.9409e-02
# Epoch 11: MSE Loss = 2.6810e-02
# Epoch 12: MSE Loss = 3.1324e-02
# Epoch 13: MSE Loss = 3.6190e-02
# Epoch 14: MSE Loss = 3.8083e-02
# Epoch 15: MSE Loss = 3.8728e-02
# Epoch 16: MSE Loss = 3.8980e-02
# Epoch 17: MSE Loss = 3.9102e-02
# Epoch 18: MSE Loss = 3.9156e-02
# Epoch 19: MSE Loss = 3.9195e-02
# Epoch 20: MSE Loss = 3.9234e-02
# Epoch 21: MSE Loss = 3.9270e-02
# Epoch 22: MSE Loss = 3.9300e-02
# Epoch 23: MSE Loss = 3.9325e-02
# Epoch 24: MSE Loss = 3.9347e-02
# Epoch 25: MSE Loss = 3.9366e-02
# Epoch 26: MSE Loss = 3.9382e-02
# Epoch 27: MSE Loss = 3.9396e-02
# Epoch 28: MSE Loss = 3.9408e-02
# Epoch 29: MSE Loss = 3.9421e-02
# Epoch 30: MSE Loss = 3.9432e-02
# Epoch 31: MSE Loss = 3.9442e-02
# Epoch 32: MSE Loss = 3.9451e-02
# Epoch 33: MSE Loss = 3.9459e-02
# Epoch 34: MSE Loss = 3.9466e-02
# Epoch 35: MSE Loss = 3.9471e-02
# Epoch 36: MSE Loss = 3.9476e-02
# Epoch 37: MSE Loss = 3.9479e-02
# Epoch 38: MSE Loss = 3.9482e-02
# Epoch 39: MSE Loss = 3.9483e-02
# Epoch 40: MSE Loss = 3.9484e-02
# Epoch 41: MSE Loss = 3.9485e-02
# Epoch 42: MSE Loss = 3.9484e-02
# Epoch 43: MSE Loss = 3.9483e-02
# Epoch 44: MSE Loss = 3.9481e-02
# Epoch 45: MSE Loss = 3.9479e-02
# Epoch 46: MSE Loss = 3.9477e-02
# Epoch 47: MSE Loss = 3.9474e-02
# Epoch 48: MSE Loss = 3.9470e-02
# Epoch 49: MSE Loss = 3.9467e-02
# Epoch 50: MSE Loss = 3.9463e-02
# Epoch 51: MSE Loss = 3.9458e-02
# Epoch 52: MSE Loss = 3.9454e-02
# Epoch 53: MSE Loss = 3.9449e-02
# Epoch 54: MSE Loss = 3.9444e-02
# Epoch 55: MSE Loss = 3.9439e-02
# Epoch 56: MSE Loss = 3.9434e-02
# Epoch 57: MSE Loss = 3.9429e-02
# Epoch 58: MSE Loss = 3.9424e-02
# Epoch 59: MSE Loss = 3.9419e-02
# Epoch 60: MSE Loss = 3.9414e-02
# Epoch 61: MSE Loss = 3.9409e-02
# Epoch 62: MSE Loss = 3.9404e-02
# Epoch 63: MSE Loss = 3.9399e-02
# Epoch 64: MSE Loss = 3.9395e-02
# Epoch 65: MSE Loss = 3.9390e-02
# Epoch 66: MSE Loss = 3.9386e-02
# Epoch 67: MSE Loss = 3.9381e-02
# Epoch 68: MSE Loss = 3.9377e-02
# Epoch 69: MSE Loss = 3.9372e-02
# Epoch 70: MSE Loss = 3.9367e-02
# Epoch 71: MSE Loss = 3.9362e-02
# Epoch 72: MSE Loss = 3.9357e-02
# Epoch 73: MSE Loss = 3.9352e-02
# Epoch 74: MSE Loss = 3.9347e-02
# Epoch 75: MSE Loss = 3.9342e-02
# Epoch 76: MSE Loss = 3.9336e-02
# Epoch 77: MSE Loss = 3.9330e-02
# Epoch 78: MSE Loss = 3.9324e-02
# Epoch 79: MSE Loss = 3.9318e-02
# Epoch 80: MSE Loss = 3.9311e-02
# Epoch 81: MSE Loss = 3.9305e-02
# Epoch 82: MSE Loss = 3.9297e-02
# Epoch 83: MSE Loss = 3.9290e-02
# Epoch 84: MSE Loss = 3.9282e-02
# Epoch 85: MSE Loss = 3.9274e-02
# Epoch 86: MSE Loss = 3.9265e-02
# Epoch 87: MSE Loss = 3.9256e-02
# Epoch 88: MSE Loss = 3.9247e-02
# Epoch 89: MSE Loss = 3.9237e-02
# Epoch 90: MSE Loss = 3.9226e-02
# Epoch 91: MSE Loss = 3.9215e-02
# Epoch 92: MSE Loss = 3.9203e-02
# Epoch 93: MSE Loss = 3.9190e-02
# Epoch 94: MSE Loss = 3.9177e-02
# Epoch 95: MSE Loss = 3.9163e-02
# Epoch 96: MSE Loss = 3.9148e-02
# Epoch 97: MSE Loss = 3.9133e-02
# Epoch 98: MSE Loss = 3.9117e-02
# Epoch 99: MSE Loss = 3.9100e-02
# Epoch 100: MSE Loss = 3.9082e-02
# Epoch 101: MSE Loss = 3.9063e-02
# Epoch 102: MSE Loss = 3.9041e-02
# Epoch 103: MSE Loss = 3.9014e-02
# Epoch 104: MSE Loss = 3.8983e-02
# Epoch 105: MSE Loss = 3.8946e-02
# Epoch 106: MSE Loss = 3.8896e-02
# Epoch 107: MSE Loss = 3.8835e-02
# Epoch 108: MSE Loss = 3.8757e-02
# Epoch 109: MSE Loss = 3.8656e-02
# Epoch 110: MSE Loss = 3.8520e-02
# Epoch 111: MSE Loss = 3.8334e-02
# Epoch 112: MSE Loss = 3.8055e-02
# Epoch 113: MSE Loss = 3.7572e-02
# Epoch 114: MSE Loss = 3.6631e-02
# Epoch 115: MSE Loss = 3.4644e-02
# Epoch 116: MSE Loss = 3.0212e-02
# Epoch 117: MSE Loss = 2.4247e-02
# Epoch 118: MSE Loss = 3.1415e-02
# Epoch 119: MSE Loss = 2.6807e-02
# Epoch 120: MSE Loss = 2.3355e-02
# Epoch 121: MSE Loss = 2.6384e-02
# Epoch 122: MSE Loss = 2.7767e-02
# Epoch 123: MSE Loss = 2.6395e-02
# Epoch 124: MSE Loss = 2.2761e-02
# Epoch 125: MSE Loss = 2.1621e-02
# Epoch 126: MSE Loss = 2.5404e-02
# Epoch 127: MSE Loss = 2.0266e-02
# Epoch 128: MSE Loss = 2.1315e-02
# Epoch 129: MSE Loss = 2.2781e-02
# Epoch 130: MSE Loss = 2.0948e-02
# Epoch 131: MSE Loss = 1.8531e-02
# Epoch 132: MSE Loss = 2.1923e-02
# Epoch 133: MSE Loss = 1.7941e-02
# Epoch 134: MSE Loss = 1.9725e-02
# Epoch 135: MSE Loss = 1.9720e-02
# Epoch 136: MSE Loss = 1.7459e-02
# Epoch 137: MSE Loss = 2.0423e-02
# Epoch 138: MSE Loss = 1.7472e-02
# Epoch 139: MSE Loss = 1.9359e-02
# Epoch 140: MSE Loss = 1.8014e-02
# Epoch 141: MSE Loss = 1.7861e-02
# Epoch 142: MSE Loss = 1.7978e-02
# Epoch 143: MSE Loss = 1.7354e-02
# Epoch 144: MSE Loss = 1.8136e-02
# Epoch 145: MSE Loss = 1.6978e-02
# Epoch 146: MSE Loss = 1.7439e-02
# Epoch 147: MSE Loss = 1.7072e-02
# Epoch 148: MSE Loss = 1.6798e-02
# Epoch 149: MSE Loss = 1.7225e-02
# Epoch 150: MSE Loss = 1.6618e-02
# Epoch 151: MSE Loss = 1.6690e-02
# Epoch 152: MSE Loss = 1.6749e-02
# Epoch 153: MSE Loss = 1.6309e-02
# Epoch 154: MSE Loss = 1.6587e-02
# Epoch 155: MSE Loss = 1.6325e-02
# Epoch 156: MSE Loss = 1.6111e-02
# Epoch 157: MSE Loss = 1.6292e-02
# Epoch 158: MSE Loss = 1.5905e-02
# Epoch 159: MSE Loss = 1.5990e-02
# Epoch 160: MSE Loss = 1.5892e-02
# Epoch 161: MSE Loss = 1.5655e-02
# Epoch 162: MSE Loss = 1.5759e-02
# Epoch 163: MSE Loss = 1.5499e-02
# Epoch 164: MSE Loss = 1.5495e-02
# Epoch 165: MSE Loss = 1.5417e-02
# Epoch 166: MSE Loss = 1.5233e-02
# Epoch 167: MSE Loss = 1.5251e-02
# Epoch 168: MSE Loss = 1.5053e-02
# Epoch 169: MSE Loss = 1.5005e-02
# Epoch 170: MSE Loss = 1.4903e-02
# Epoch 171: MSE Loss = 1.4746e-02
# Epoch 172: MSE Loss = 1.4699e-02
# Epoch 173: MSE Loss = 1.4530e-02
# Epoch 174: MSE Loss = 1.4450e-02
# Epoch 175: MSE Loss = 1.4334e-02
# Epoch 176: MSE Loss = 1.4187e-02
# Epoch 177: MSE Loss = 1.4100e-02
# Epoch 178: MSE Loss = 1.3941e-02
# Epoch 179: MSE Loss = 1.3825e-02
# Epoch 180: MSE Loss = 1.3692e-02
# Epoch 181: MSE Loss = 1.3529e-02
# Epoch 182: MSE Loss = 1.3404e-02
# Epoch 183: MSE Loss = 1.3234e-02
# Epoch 184: MSE Loss = 1.3084e-02
# Epoch 185: MSE Loss = 1.2926e-02
# Epoch 186: MSE Loss = 1.2748e-02
# Epoch 187: MSE Loss = 1.2591e-02
# Epoch 188: MSE Loss = 1.2403e-02
# Epoch 189: MSE Loss = 1.2233e-02
# Epoch 190: MSE Loss = 1.2045e-02
# Epoch 191: MSE Loss = 1.1857e-02
# Epoch 192: MSE Loss = 1.1673e-02
# Epoch 193: MSE Loss = 1.1472e-02
# Epoch 194: MSE Loss = 1.1282e-02
# Epoch 195: MSE Loss = 1.1080e-02
# Epoch 196: MSE Loss = 1.0877e-02
# Epoch 197: MSE Loss = 1.0677e-02
# Epoch 198: MSE Loss = 1.0468e-02
# Epoch 199: MSE Loss = 1.0265e-02
# Epoch 200: MSE Loss = 1.0054e-02
# Epoch 201: MSE Loss = 9.8456e-03
# Epoch 202: MSE Loss = 9.6353e-03
# Epoch 203: MSE Loss = 9.4218e-03
# Epoch 204: MSE Loss = 9.2120e-03
# Epoch 205: MSE Loss = 8.9988e-03
# Epoch 206: MSE Loss = 8.7880e-03
# Epoch 207: MSE Loss = 8.5775e-03
# Epoch 208: MSE Loss = 8.3658e-03
# Epoch 209: MSE Loss = 8.1566e-03
# Epoch 210: MSE Loss = 7.9463e-03
# Epoch 211: MSE Loss = 7.7392e-03
# Epoch 212: MSE Loss = 7.5351e-03
# Epoch 213: MSE Loss = 7.3332e-03
# Epoch 214: MSE Loss = 7.1360e-03
# Epoch 215: MSE Loss = 6.9401e-03
# Epoch 216: MSE Loss = 6.7482e-03
# Epoch 217: MSE Loss = 6.5589e-03
# Epoch 218: MSE Loss = 6.3726e-03
# Epoch 219: MSE Loss = 6.1900e-03
# Epoch 220: MSE Loss = 6.0099e-03
# Epoch 221: MSE Loss = 5.8338e-03
# Epoch 222: MSE Loss = 5.6609e-03
# Epoch 223: MSE Loss = 5.4915e-03
# Epoch 224: MSE Loss = 5.3257e-03
# Epoch 225: MSE Loss = 5.1628e-03
# Epoch 226: MSE Loss = 5.0039e-03
# Epoch 227: MSE Loss = 4.8495e-03
# Epoch 228: MSE Loss = 4.7000e-03
# Epoch 229: MSE Loss = 4.5550e-03
# Epoch 230: MSE Loss = 4.4143e-03
# Epoch 231: MSE Loss = 4.2780e-03
# Epoch 232: MSE Loss = 4.1460e-03
# Epoch 233: MSE Loss = 4.0181e-03
# Epoch 234: MSE Loss = 3.8944e-03
# Epoch 235: MSE Loss = 3.7748e-03
# Epoch 236: MSE Loss = 3.6591e-03
# Epoch 237: MSE Loss = 3.5472e-03
# Epoch 238: MSE Loss = 3.4388e-03
# Epoch 239: MSE Loss = 3.3338e-03
# Epoch 240: MSE Loss = 3.2322e-03
# Epoch 241: MSE Loss = 3.1340e-03
# Epoch 242: MSE Loss = 3.0391e-03
# Epoch 243: MSE Loss = 2.9473e-03
# Epoch 244: MSE Loss = 2.8585e-03
# Epoch 245: MSE Loss = 2.7725e-03
# Epoch 246: MSE Loss = 2.6894e-03
# Epoch 247: MSE Loss = 2.6090e-03
# Epoch 248: MSE Loss = 2.5311e-03
# Epoch 249: MSE Loss = 2.4558e-03
# Epoch 250: MSE Loss = 2.3829e-03
# Epoch 251: MSE Loss = 2.3125e-03
# Epoch 252: MSE Loss = 2.2442e-03
# Epoch 253: MSE Loss = 2.1781e-03
# Epoch 254: MSE Loss = 2.1141e-03
# Epoch 255: MSE Loss = 2.0522e-03
# Epoch 256: MSE Loss = 1.9922e-03
# Epoch 257: MSE Loss = 1.9342e-03
# Epoch 258: MSE Loss = 1.8780e-03
# Epoch 259: MSE Loss = 1.8237e-03
# Epoch 260: MSE Loss = 1.7710e-03
# Epoch 261: MSE Loss = 1.7200e-03
# Epoch 262: MSE Loss = 1.6705e-03
# Epoch 263: MSE Loss = 1.6228e-03
# Epoch 264: MSE Loss = 1.5766e-03
# Epoch 265: MSE Loss = 1.5320e-03
# Epoch 266: MSE Loss = 1.4889e-03
# Epoch 267: MSE Loss = 1.4473e-03
# Epoch 268: MSE Loss = 1.4071e-03
# Epoch 269: MSE Loss = 1.3683e-03
# Epoch 270: MSE Loss = 1.3306e-03
# Epoch 271: MSE Loss = 1.2948e-03
# Epoch 272: MSE Loss = 1.2591e-03
# Epoch 273: MSE Loss = 1.2251e-03
# Epoch 274: MSE Loss = 1.1921e-03
# Epoch 275: MSE Loss = 1.1603e-03
# Epoch 276: MSE Loss = 1.1295e-03
# Epoch 277: MSE Loss = 1.0996e-03
# Epoch 278: MSE Loss = 1.0707e-03
# Epoch 279: MSE Loss = 1.0427e-03
# Epoch 280: MSE Loss = 1.0157e-03
# Epoch 281: MSE Loss = 9.8924e-04
# Epoch 282: MSE Loss = 9.6376e-04
# Epoch 283: MSE Loss = 9.3921e-04
# Epoch 284: MSE Loss = 9.1502e-04
# Epoch 285: MSE Loss = 8.9173e-04
# Epoch 286: MSE Loss = 8.6917e-04
# Epoch 287: MSE Loss = 8.4725e-04
# Epoch 288: MSE Loss = 8.2599e-04
# Epoch 289: MSE Loss = 8.0535e-04
# Epoch 290: MSE Loss = 7.8531e-04
# Epoch 291: MSE Loss = 7.6586e-04
# Epoch 292: MSE Loss = 7.4694e-04
# Epoch 293: MSE Loss = 7.2861e-04
# Epoch 294: MSE Loss = 7.1069e-04
# Epoch 295: MSE Loss = 6.9334e-04
# Epoch 296: MSE Loss = 6.7666e-04
# Epoch 297: MSE Loss = 6.6008e-04
# Epoch 298: MSE Loss = 6.4412e-04
# Epoch 299: MSE Loss = 6.2859e-04
# Epoch 300: MSE Loss = 6.1352e-04
# Epoch 301: MSE Loss = 5.9883e-04
# Epoch 302: MSE Loss = 5.8455e-04
# Epoch 303: MSE Loss = 5.7079e-04
# Epoch 304: MSE Loss = 5.5712e-04
# Epoch 305: MSE Loss = 5.4395e-04
# Epoch 306: MSE Loss = 5.3115e-04
# Epoch 307: MSE Loss = 5.1867e-04
# Epoch 308: MSE Loss = 5.0651e-04
# Epoch 309: MSE Loss = 4.9467e-04
# Epoch 310: MSE Loss = 4.8317e-04
# Epoch 311: MSE Loss = 4.7194e-04
# Epoch 312: MSE Loss = 4.6098e-04
# Epoch 313: MSE Loss = 4.5033e-04
# Epoch 314: MSE Loss = 4.3995e-04
# Epoch 315: MSE Loss = 4.2983e-04
# Epoch 316: MSE Loss = 4.1997e-04
# Epoch 317: MSE Loss = 4.1036e-04
# Epoch 318: MSE Loss = 4.0100e-04
# Epoch 319: MSE Loss = 3.9187e-04
# Epoch 320: MSE Loss = 3.8296e-04
# Epoch 321: MSE Loss = 3.7429e-04
# Epoch 322: MSE Loss = 3.6582e-04
# Epoch 323: MSE Loss = 3.5757e-04
# Epoch 324: MSE Loss = 3.4952e-04
# Epoch 325: MSE Loss = 3.4167e-04
# Epoch 326: MSE Loss = 3.3401e-04
# Epoch 327: MSE Loss = 3.2655e-04
# Epoch 328: MSE Loss = 3.1926e-04
# Epoch 329: MSE Loss = 3.1215e-04
# Epoch 330: MSE Loss = 3.0521e-04
# Epoch 331: MSE Loss = 2.9847e-04
# Epoch 332: MSE Loss = 2.9185e-04
# Epoch 333: MSE Loss = 2.8541e-04
# Epoch 334: MSE Loss = 2.7912e-04
# Epoch 335: MSE Loss = 2.7299e-04
# Epoch 336: MSE Loss = 2.6700e-04
# Epoch 337: MSE Loss = 2.6116e-04
# Epoch 338: MSE Loss = 2.5545e-04
# Epoch 339: MSE Loss = 2.4989e-04
# Epoch 340: MSE Loss = 2.4446e-04
# Epoch 341: MSE Loss = 2.3915e-04
# Epoch 342: MSE Loss = 2.3396e-04
# Epoch 343: MSE Loss = 2.2891e-04
# Epoch 344: MSE Loss = 2.2392e-04
# Epoch 345: MSE Loss = 2.1916e-04
# Epoch 346: MSE Loss = 2.1444e-04
# Epoch 347: MSE Loss = 2.0985e-04
# Epoch 348: MSE Loss = 2.0536e-04
# Epoch 349: MSE Loss = 2.0097e-04
# Epoch 350: MSE Loss = 1.9670e-04
# Epoch 351: MSE Loss = 1.9251e-04
# Epoch 352: MSE Loss = 1.8843e-04
# Epoch 353: MSE Loss = 1.8444e-04
# Epoch 354: MSE Loss = 1.8055e-04
# Epoch 355: MSE Loss = 1.7675e-04
# Epoch 356: MSE Loss = 1.7305e-04
# Epoch 357: MSE Loss = 1.6940e-04
# Epoch 358: MSE Loss = 1.6586e-04
# Epoch 359: MSE Loss = 1.6239e-04
# Epoch 360: MSE Loss = 1.5901e-04
# Epoch 361: MSE Loss = 1.5570e-04
# Epoch 362: MSE Loss = 1.5248e-04
# Epoch 363: MSE Loss = 1.4933e-04
# Epoch 364: MSE Loss = 1.4624e-04
# Epoch 365: MSE Loss = 1.4323e-04
# Epoch 366: MSE Loss = 1.4028e-04
# Epoch 367: MSE Loss = 1.3740e-04
# Epoch 368: MSE Loss = 1.3459e-04
# Epoch 369: MSE Loss = 1.3184e-04
# Epoch 370: MSE Loss = 1.2916e-04
# Epoch 371: MSE Loss = 1.2653e-04
# Epoch 372: MSE Loss = 1.2396e-04
# Epoch 373: MSE Loss = 1.2145e-04
# Epoch 374: MSE Loss = 1.1900e-04
# Epoch 375: MSE Loss = 1.1660e-04
# Epoch 376: MSE Loss = 1.1426e-04
# Epoch 377: MSE Loss = 1.1196e-04
# Epoch 378: MSE Loss = 1.0972e-04
# Epoch 379: MSE Loss = 1.0754e-04
# Epoch 380: MSE Loss = 1.0539e-04
# Epoch 381: MSE Loss = 1.0330e-04
# Epoch 382: MSE Loss = 1.0125e-04
# Epoch 383: MSE Loss = 9.9250e-05
# Epoch 384: MSE Loss = 9.7291e-05
# Epoch 385: MSE Loss = 9.5378e-05
# Epoch 386: MSE Loss = 9.3521e-05
# Epoch 387: MSE Loss = 9.1670e-05
# Epoch 388: MSE Loss = 8.9888e-05
# Epoch 389: MSE Loss = 8.8143e-05
# Epoch 390: MSE Loss = 8.6421e-05
# Epoch 391: MSE Loss = 8.4739e-05
# Epoch 392: MSE Loss = 8.3105e-05
# Epoch 393: MSE Loss = 8.1502e-05
# Epoch 394: MSE Loss = 7.9949e-05
# Epoch 395: MSE Loss = 7.8401e-05
# Epoch 396: MSE Loss = 7.6898e-05
# Epoch 397: MSE Loss = 7.5431e-05
# Epoch 398: MSE Loss = 7.3994e-05
# Epoch 399: MSE Loss = 7.2591e-05
# Epoch 400: MSE Loss = 7.1213e-05
# Epoch 401: MSE Loss = 6.9873e-05
# Epoch 402: MSE Loss = 6.8558e-05
# Epoch 403: MSE Loss = 6.7262e-05
# Epoch 404: MSE Loss = 6.6005e-05
# Epoch 405: MSE Loss = 6.4771e-05
# Epoch 406: MSE Loss = 6.3564e-05
# Epoch 407: MSE Loss = 6.2395e-05
# Epoch 408: MSE Loss = 6.1225e-05
# Epoch 409: MSE Loss = 6.0091e-05
# Epoch 410: MSE Loss = 5.8986e-05
# Epoch 411: MSE Loss = 5.7898e-05
# Epoch 412: MSE Loss = 5.6840e-05
# Epoch 413: MSE Loss = 5.5797e-05
# Epoch 414: MSE Loss = 5.4786e-05
# Epoch 415: MSE Loss = 5.3786e-05
# Epoch 416: MSE Loss = 5.2810e-05
# Epoch 417: MSE Loss = 5.1852e-05
# Epoch 418: MSE Loss = 5.0919e-05
# Epoch 419: MSE Loss = 5.0004e-05
# Epoch 420: MSE Loss = 4.9106e-05
# Epoch 421: MSE Loss = 4.8235e-05
# Epoch 422: MSE Loss = 4.7376e-05
# Epoch 423: MSE Loss = 4.6532e-05
# Epoch 424: MSE Loss = 4.5711e-05
# Epoch 425: MSE Loss = 4.4905e-05
# Epoch 426: MSE Loss = 4.4111e-05
# Epoch 427: MSE Loss = 4.3341e-05
# Epoch 428: MSE Loss = 4.2580e-05
# Epoch 429: MSE Loss = 4.1844e-05
# Epoch 430: MSE Loss = 4.1124e-05
# Epoch 431: MSE Loss = 4.0403e-05
# Epoch 432: MSE Loss = 3.9795e-05
# Epoch 433: MSE Loss = 3.9020e-05
# Epoch 434: MSE Loss = 3.8355e-05
# Epoch 435: MSE Loss = 3.7704e-05
# Epoch 436: MSE Loss = 3.7058e-05
# Epoch 437: MSE Loss = 3.6428e-05
# Epoch 438: MSE Loss = 3.5815e-05
# Epoch 439: MSE Loss = 3.5209e-05
# Epoch 440: MSE Loss = 3.4617e-05
# Epoch 441: MSE Loss = 3.4063e-05
# Epoch 442: MSE Loss = 3.3476e-05
# Epoch 443: MSE Loss = 3.2915e-05
# Epoch 444: MSE Loss = 3.2367e-05
# Epoch 445: MSE Loss = 3.1832e-05
# Epoch 446: MSE Loss = 3.1310e-05
# Epoch 447: MSE Loss = 3.0702e-05
# Epoch 448: MSE Loss = 3.0291e-05
# Epoch 449: MSE Loss = 2.9797e-05
# Epoch 450: MSE Loss = 2.9312e-05
# Epoch 451: MSE Loss = 2.8839e-05
# Epoch 452: MSE Loss = 2.8375e-05
# Epoch 453: MSE Loss = 2.7919e-05
# Epoch 454: MSE Loss = 2.7474e-05
# Epoch 455: MSE Loss = 2.7037e-05
# Epoch 456: MSE Loss = 2.6604e-05
# Epoch 457: MSE Loss = 2.6181e-05
# Epoch 458: MSE Loss = 2.5768e-05
# Epoch 459: MSE Loss = 2.5364e-05
# Epoch 460: MSE Loss = 2.4968e-05
# Epoch 461: MSE Loss = 2.4578e-05
# Epoch 462: MSE Loss = 2.4195e-05
# Epoch 463: MSE Loss = 2.3819e-05
# Epoch 464: MSE Loss = 2.3455e-05
# Epoch 465: MSE Loss = 2.3096e-05
# Epoch 466: MSE Loss = 2.2737e-05
# Epoch 467: MSE Loss = 2.2393e-05
# Epoch 468: MSE Loss = 2.2053e-05
# Epoch 469: MSE Loss = 2.1719e-05
# Epoch 470: MSE Loss = 2.1393e-05
# Epoch 471: MSE Loss = 2.1067e-05
# Epoch 472: MSE Loss = 2.0753e-05
# Epoch 473: MSE Loss = 2.0444e-05
# Epoch 474: MSE Loss = 2.0141e-05
# Epoch 475: MSE Loss = 1.9843e-05
# Epoch 476: MSE Loss = 1.9644e-05
# Epoch 477: MSE Loss = 1.9268e-05
# Epoch 478: MSE Loss = 1.8985e-05
# Epoch 479: MSE Loss = 1.8710e-05
# Epoch 480: MSE Loss = 1.8436e-05
# Epoch 481: MSE Loss = 1.8170e-05
# Epoch 482: MSE Loss = 1.7922e-05
# Epoch 483: MSE Loss = 1.7654e-05
# Epoch 484: MSE Loss = 1.7399e-05
# Epoch 485: MSE Loss = 1.7154e-05
# Epoch 486: MSE Loss = 1.6911e-05
# Epoch 487: MSE Loss = 1.6674e-05
# Epoch 488: MSE Loss = 1.6442e-05
# Epoch 489: MSE Loss = 1.6211e-05
# Epoch 490: MSE Loss = 1.5986e-05
# Epoch 491: MSE Loss = 1.5765e-05
# Epoch 492: MSE Loss = 1.5548e-05
# Epoch 493: MSE Loss = 1.5337e-05
# Epoch 494: MSE Loss = 1.5126e-05
# Epoch 495: MSE Loss = 1.4922e-05
# Epoch 496: MSE Loss = 1.4718e-05
# Epoch 497: MSE Loss = 1.4523e-05
# Epoch 498: MSE Loss = 1.4324e-05
# Epoch 499: MSE Loss = 1.4133e-05
# Epoch 500: MSE Loss = 1.3947e-05
# Epoch 501: MSE Loss = 1.3762e-05
# Epoch 502: MSE Loss = 1.3583e-05
# Epoch 503: MSE Loss = 1.3404e-05
# Epoch 504: MSE Loss = 1.3228e-05
# Epoch 505: MSE Loss = 1.3056e-05
# Epoch 506: MSE Loss = 1.2889e-05
# Epoch 507: MSE Loss = 1.2723e-05
# Epoch 508: MSE Loss = 1.2559e-05
# Epoch 509: MSE Loss = 1.2403e-05
# Epoch 510: MSE Loss = 1.2242e-05
# Epoch 511: MSE Loss = 1.2104e-05
# Epoch 512: MSE Loss = 1.1937e-05
# Epoch 513: MSE Loss = 1.1787e-05
# Epoch 514: MSE Loss = 1.1707e-05
# Epoch 515: MSE Loss = 1.1496e-05
# Epoch 516: MSE Loss = 1.1354e-05
# Epoch 517: MSE Loss = 1.1215e-05
# Epoch 518: MSE Loss = 1.1089e-05
# Epoch 519: MSE Loss = 1.0944e-05
# Epoch 520: MSE Loss = 1.0812e-05
# Epoch 521: MSE Loss = 1.0681e-05
# Epoch 522: MSE Loss = 1.0554e-05
# Epoch 523: MSE Loss = 1.0426e-05
# Epoch 524: MSE Loss = 1.0250e-05
# Epoch 525: MSE Loss = 1.0180e-05
# Epoch 526: MSE Loss = 1.0061e-05
# Epoch 527: MSE Loss = 9.9448e-06
# Epoch 528: MSE Loss = 9.8298e-06
# Epoch 529: MSE Loss = 9.7169e-06
# Epoch 530: MSE Loss = 9.6172e-06
# Epoch 531: MSE Loss = 9.4923e-06
# Epoch 532: MSE Loss = 9.3850e-06
# Epoch 533: MSE Loss = 9.2778e-06
# Epoch 534: MSE Loss = 9.1741e-06
# Epoch 535: MSE Loss = 9.0708e-06
# Epoch 536: MSE Loss = 8.9713e-06
# Epoch 537: MSE Loss = 8.8663e-06
# Epoch 538: MSE Loss = 8.7709e-06
# Epoch 539: MSE Loss = 8.6751e-06
# Epoch 540: MSE Loss = 8.5829e-06
# Epoch 541: MSE Loss = 8.4860e-06
# Epoch 542: MSE Loss = 8.3943e-06
# Epoch 543: MSE Loss = 8.3065e-06
# Epoch 544: MSE Loss = 8.2158e-06
# Epoch 545: MSE Loss = 8.1292e-06
# Epoch 546: MSE Loss = 8.0404e-06
# Epoch 547: MSE Loss = 7.9566e-06
# Epoch 548: MSE Loss = 7.8729e-06
# Epoch 549: MSE Loss = 7.7904e-06
# Epoch 550: MSE Loss = 7.7108e-06
# Epoch 551: MSE Loss = 7.6322e-06
# Epoch 552: MSE Loss = 7.5527e-06
# Epoch 553: MSE Loss = 7.4753e-06
# Epoch 554: MSE Loss = 7.4012e-06
# Epoch 555: MSE Loss = 7.3241e-06
# Epoch 556: MSE Loss = 7.2492e-06
# Epoch 557: MSE Loss = 7.1785e-06
# Epoch 558: MSE Loss = 7.1612e-06
# Epoch 559: MSE Loss = 7.0360e-06
# Epoch 560: MSE Loss = 6.9662e-06
# Epoch 561: MSE Loss = 6.8991e-06
# Epoch 562: MSE Loss = 6.8317e-06
# Epoch 563: MSE Loss = 6.7685e-06
# Epoch 564: MSE Loss = 6.7007e-06
# Epoch 565: MSE Loss = 6.6368e-06
# Epoch 566: MSE Loss = 6.5739e-06
# Epoch 567: MSE Loss = 6.5120e-06
# Epoch 568: MSE Loss = 6.4522e-06
# Epoch 569: MSE Loss = 6.3916e-06
# Epoch 570: MSE Loss = 6.3310e-06
# Epoch 571: MSE Loss = 6.2723e-06
# Epoch 572: MSE Loss = 6.2157e-06
# Epoch 573: MSE Loss = 6.1570e-06
# Epoch 574: MSE Loss = 6.1024e-06
# Epoch 575: MSE Loss = 6.0462e-06
# Epoch 576: MSE Loss = 5.9912e-06
# Epoch 577: MSE Loss = 5.9375e-06
# Epoch 578: MSE Loss = 5.8849e-06
# Epoch 579: MSE Loss = 5.8332e-06
# Epoch 580: MSE Loss = 5.7816e-06
# Epoch 581: MSE Loss = 5.7293e-06
# Epoch 582: MSE Loss = 5.6787e-06
# Epoch 583: MSE Loss = 5.6289e-06
# Epoch 584: MSE Loss = 5.5820e-06
# Epoch 585: MSE Loss = 5.5343e-06
# Epoch 586: MSE Loss = 5.5330e-06
# Epoch 587: MSE Loss = 5.4428e-06
# Epoch 588: MSE Loss = 5.3956e-06
# Epoch 589: MSE Loss = 5.3517e-06
# Epoch 590: MSE Loss = 5.3081e-06
# Epoch 591: MSE Loss = 5.2626e-06
# Epoch 592: MSE Loss = 5.2212e-06
# Epoch 593: MSE Loss = 5.1756e-06
# Epoch 594: MSE Loss = 5.1329e-06
# Epoch 595: MSE Loss = 5.0919e-06
# Epoch 596: MSE Loss = 5.0504e-06
# Epoch 597: MSE Loss = 5.0111e-06
# Epoch 598: MSE Loss = 4.9723e-06
# Epoch 599: MSE Loss = 4.9314e-06
# Epoch 600: MSE Loss = 4.8951e-06
# Epoch 601: MSE Loss = 4.8557e-06
# Epoch 602: MSE Loss = 4.8180e-06
# Epoch 603: MSE Loss = 4.7796e-06
# Epoch 604: MSE Loss = 4.7429e-06
# Epoch 605: MSE Loss = 4.7059e-06
# Epoch 606: MSE Loss = 4.6728e-06
# Epoch 607: MSE Loss = 4.6359e-06
# Epoch 608: MSE Loss = 4.6017e-06
# Epoch 609: MSE Loss = 4.5678e-06
# Epoch 610: MSE Loss = 4.5330e-06
# Epoch 611: MSE Loss = 4.5014e-06
# Epoch 612: MSE Loss = 4.4672e-06
# Epoch 613: MSE Loss = 4.4355e-06
# Epoch 614: MSE Loss = 4.4041e-06
# Epoch 615: MSE Loss = 4.3724e-06
# Epoch 616: MSE Loss = 4.3411e-06
# Epoch 617: MSE Loss = 4.3096e-06
# Epoch 618: MSE Loss = 4.2791e-06
# Epoch 619: MSE Loss = 4.2499e-06
# Epoch 620: MSE Loss = 4.2200e-06
# Epoch 621: MSE Loss = 4.1904e-06
# Epoch 622: MSE Loss = 4.1633e-06
# Epoch 623: MSE Loss = 4.1340e-06
# Epoch 624: MSE Loss = 4.1067e-06
# Epoch 625: MSE Loss = 4.0809e-06
# Epoch 626: MSE Loss = 4.0505e-06
# Epoch 627: MSE Loss = 4.0231e-06
# Epoch 628: MSE Loss = 3.9968e-06
# Epoch 629: MSE Loss = 3.9702e-06
# Epoch 630: MSE Loss = 3.9444e-06
# Epoch 631: MSE Loss = 3.9208e-06
# Epoch 632: MSE Loss = 3.8930e-06
# Epoch 633: MSE Loss = 3.8696e-06
# Epoch 634: MSE Loss = 3.8480e-06
# Epoch 635: MSE Loss = 3.8187e-06
# Epoch 636: MSE Loss = 3.7970e-06
# Epoch 637: MSE Loss = 3.7719e-06
# Epoch 638: MSE Loss = 3.7480e-06
# Epoch 639: MSE Loss = 3.7241e-06
# Epoch 640: MSE Loss = 3.7018e-06
# Epoch 641: MSE Loss = 3.6794e-06
# Epoch 642: MSE Loss = 3.6576e-06
# Epoch 643: MSE Loss = 3.6394e-06
# Epoch 644: MSE Loss = 3.6130e-06
# Epoch 645: MSE Loss = 3.5930e-06
# Epoch 646: MSE Loss = 3.5710e-06
# Epoch 647: MSE Loss = 3.5505e-06
# Epoch 648: MSE Loss = 3.5275e-06
# Epoch 649: MSE Loss = 3.5080e-06
# Epoch 650: MSE Loss = 3.4886e-06
# Epoch 651: MSE Loss = 3.4680e-06
# Epoch 652: MSE Loss = 3.4480e-06
# Epoch 653: MSE Loss = 3.4283e-06
# Epoch 654: MSE Loss = 3.4083e-06
# Epoch 655: MSE Loss = 3.3901e-06
# Epoch 656: MSE Loss = 3.3713e-06
# Epoch 657: MSE Loss = 3.3529e-06
# Epoch 658: MSE Loss = 3.3337e-06
# Epoch 659: MSE Loss = 3.3169e-06
# Epoch 660: MSE Loss = 3.2979e-06
# Epoch 661: MSE Loss = 3.2805e-06
# Epoch 662: MSE Loss = 3.2641e-06
# Epoch 663: MSE Loss = 3.2456e-06
# Epoch 664: MSE Loss = 3.2297e-06
# Epoch 665: MSE Loss = 3.2104e-06
# Epoch 666: MSE Loss = 3.1952e-06
# Epoch 667: MSE Loss = 3.1787e-06
# Epoch 668: MSE Loss = 3.1622e-06
# Epoch 669: MSE Loss = 3.1455e-06
# Epoch 670: MSE Loss = 3.1297e-06
# Epoch 671: MSE Loss = 3.1154e-06
# Epoch 672: MSE Loss = 3.1000e-06
# Epoch 673: MSE Loss = 3.0828e-06
# Epoch 674: MSE Loss = 3.0683e-06
# Epoch 675: MSE Loss = 3.0528e-06
# Epoch 676: MSE Loss = 3.0382e-06
# Epoch 677: MSE Loss = 3.0235e-06
# Epoch 678: MSE Loss = 3.0092e-06
# Epoch 679: MSE Loss = 2.9951e-06
# Epoch 680: MSE Loss = 2.9813e-06
# Epoch 681: MSE Loss = 2.9659e-06
# Epoch 682: MSE Loss = 2.9517e-06
# Epoch 683: MSE Loss = 2.9391e-06
# Epoch 684: MSE Loss = 2.9246e-06
# Epoch 685: MSE Loss = 2.9131e-06
# Epoch 686: MSE Loss = 2.8976e-06
# Epoch 687: MSE Loss = 2.8841e-06
# Epoch 688: MSE Loss = 2.8714e-06
# Epoch 689: MSE Loss = 2.8621e-06
# Epoch 690: MSE Loss = 2.8457e-06
# Epoch 691: MSE Loss = 2.8326e-06
# Epoch 692: MSE Loss = 2.8202e-06
# Epoch 693: MSE Loss = 2.8083e-06
# Epoch 694: MSE Loss = 2.7975e-06
# Epoch 695: MSE Loss = 2.7836e-06
# Epoch 696: MSE Loss = 2.7715e-06
# Epoch 697: MSE Loss = 2.7601e-06
# Epoch 698: MSE Loss = 2.7555e-06
# Epoch 699: MSE Loss = 2.7427e-06
# Epoch 700: MSE Loss = 2.7253e-06
# Epoch 701: MSE Loss = 2.7140e-06
# Epoch 702: MSE Loss = 2.7024e-06
# Epoch 703: MSE Loss = 2.6916e-06
# Epoch 704: MSE Loss = 2.6804e-06
# Epoch 705: MSE Loss = 2.6707e-06
# Epoch 706: MSE Loss = 2.6586e-06
# Epoch 707: MSE Loss = 2.6484e-06
# Epoch 708: MSE Loss = 2.6394e-06
# Epoch 709: MSE Loss = 2.6292e-06
# Epoch 710: MSE Loss = 2.6174e-06
# Epoch 711: MSE Loss = 2.6079e-06
# Epoch 712: MSE Loss = 2.5972e-06
# Epoch 713: MSE Loss = 2.5867e-06
# Epoch 714: MSE Loss = 2.5777e-06
# Epoch 715: MSE Loss = 2.5759e-06
# Epoch 716: MSE Loss = 2.5595e-06
# Epoch 717: MSE Loss = 2.5482e-06
# Epoch 718: MSE Loss = 2.5403e-06
# Epoch 719: MSE Loss = 2.5306e-06
# Epoch 720: MSE Loss = 2.5209e-06
# Epoch 721: MSE Loss = 2.5100e-06
# Epoch 722: MSE Loss = 2.5042e-06
# Epoch 723: MSE Loss = 2.4944e-06
# Epoch 724: MSE Loss = 2.4863e-06
# Epoch 725: MSE Loss = 2.4749e-06
# Epoch 726: MSE Loss = 2.4678e-06
# Epoch 727: MSE Loss = 2.4575e-06
# Epoch 728: MSE Loss = 2.4500e-06
# Epoch 729: MSE Loss = 2.4407e-06
# Epoch 730: MSE Loss = 2.4325e-06
# Epoch 731: MSE Loss = 2.4238e-06
# Epoch 732: MSE Loss = 2.4150e-06
# Epoch 733: MSE Loss = 2.4074e-06
# Epoch 734: MSE Loss = 2.3985e-06
# Epoch 735: MSE Loss = 2.3915e-06
# Epoch 736: MSE Loss = 2.3851e-06
# Epoch 737: MSE Loss = 2.3776e-06
# Epoch 738: MSE Loss = 2.3671e-06
# Epoch 739: MSE Loss = 2.3601e-06
# Epoch 740: MSE Loss = 2.3520e-06
# Epoch 741: MSE Loss = 2.3444e-06
# Epoch 742: MSE Loss = 2.3374e-06
# Epoch 743: MSE Loss = 2.3294e-06
# Epoch 744: MSE Loss = 2.3224e-06
# Epoch 745: MSE Loss = 2.3152e-06
# Epoch 746: MSE Loss = 2.3087e-06
# Epoch 747: MSE Loss = 2.3013e-06
# Epoch 748: MSE Loss = 2.2943e-06
# Epoch 749: MSE Loss = 2.2876e-06
# Epoch 750: MSE Loss = 2.2803e-06
# Epoch 751: MSE Loss = 2.2730e-06
# Epoch 752: MSE Loss = 2.2668e-06
# Epoch 753: MSE Loss = 2.2595e-06
# Epoch 754: MSE Loss = 2.2538e-06
# Epoch 755: MSE Loss = 2.2490e-06
# Epoch 756: MSE Loss = 2.2396e-06
# Epoch 757: MSE Loss = 2.2340e-06
# Epoch 758: MSE Loss = 2.2269e-06
# Epoch 759: MSE Loss = 2.2222e-06
# Epoch 760: MSE Loss = 2.2146e-06
# Epoch 761: MSE Loss = 2.2084e-06
# Epoch 762: MSE Loss = 2.2013e-06
# Epoch 763: MSE Loss = 2.1956e-06
# Epoch 764: MSE Loss = 2.1904e-06
# Epoch 765: MSE Loss = 2.1836e-06
# Epoch 766: MSE Loss = 2.1778e-06
# Epoch 767: MSE Loss = 2.1727e-06
# Epoch 768: MSE Loss = 2.1661e-06
# Epoch 769: MSE Loss = 2.1596e-06
# Epoch 770: MSE Loss = 2.1553e-06
# Epoch 771: MSE Loss = 2.1480e-06
# Epoch 772: MSE Loss = 2.1423e-06
# Epoch 773: MSE Loss = 2.1367e-06
# Epoch 774: MSE Loss = 2.1308e-06
# Epoch 775: MSE Loss = 2.1256e-06
# Epoch 776: MSE Loss = 2.1199e-06
# Epoch 777: MSE Loss = 2.1146e-06
# Epoch 778: MSE Loss = 2.1090e-06
# Epoch 779: MSE Loss = 2.1038e-06
# Epoch 780: MSE Loss = 2.0982e-06
# Epoch 781: MSE Loss = 2.0929e-06
# Epoch 782: MSE Loss = 2.0900e-06
# Epoch 783: MSE Loss = 2.0843e-06
# Epoch 784: MSE Loss = 2.0794e-06
# Epoch 785: MSE Loss = 2.0725e-06
# Epoch 786: MSE Loss = 2.0686e-06
# Epoch 787: MSE Loss = 2.0626e-06
# Epoch 788: MSE Loss = 2.0581e-06
# Epoch 789: MSE Loss = 2.0527e-06
# Epoch 790: MSE Loss = 2.0470e-06
# Epoch 791: MSE Loss = 2.0433e-06
# Epoch 792: MSE Loss = 2.0386e-06
# Epoch 793: MSE Loss = 2.0333e-06
# Epoch 794: MSE Loss = 2.0282e-06
# Epoch 795: MSE Loss = 2.0237e-06
# Epoch 796: MSE Loss = 2.0185e-06
# Epoch 797: MSE Loss = 2.0142e-06
# Epoch 798: MSE Loss = 2.0107e-06
# Epoch 799: MSE Loss = 2.0049e-06
# Epoch 800: MSE Loss = 1.9996e-06
# Epoch 801: MSE Loss = 1.9970e-06
# Epoch 802: MSE Loss = 1.9917e-06
# Epoch 803: MSE Loss = 1.9868e-06
# Epoch 804: MSE Loss = 1.9827e-06
# Epoch 805: MSE Loss = 1.9786e-06
# Epoch 806: MSE Loss = 1.9735e-06
# Epoch 807: MSE Loss = 1.9691e-06
# Epoch 808: MSE Loss = 1.9653e-06
# Epoch 809: MSE Loss = 1.9614e-06
# Epoch 810: MSE Loss = 1.9562e-06
# Epoch 811: MSE Loss = 1.9522e-06
# Epoch 812: MSE Loss = 1.9478e-06
# Epoch 813: MSE Loss = 1.9448e-06
# Epoch 814: MSE Loss = 1.9401e-06
# Epoch 815: MSE Loss = 1.9368e-06
# Epoch 816: MSE Loss = 1.9314e-06
# Epoch 817: MSE Loss = 1.9274e-06
# Epoch 818: MSE Loss = 1.9247e-06
# Epoch 819: MSE Loss = 1.9208e-06
# Epoch 820: MSE Loss = 1.9159e-06
# Epoch 821: MSE Loss = 1.9120e-06
# Epoch 822: MSE Loss = 1.9076e-06
# Epoch 823: MSE Loss = 1.9031e-06
# Epoch 824: MSE Loss = 1.9001e-06
# Epoch 825: MSE Loss = 1.8967e-06
# Epoch 826: MSE Loss = 1.8922e-06
# Epoch 827: MSE Loss = 1.8893e-06
# Epoch 828: MSE Loss = 1.8821e-06
# Epoch 829: MSE Loss = 1.8787e-06
# Epoch 830: MSE Loss = 1.8779e-06
# Epoch 831: MSE Loss = 1.8743e-06
# Epoch 832: MSE Loss = 1.8703e-06
# Epoch 833: MSE Loss = 1.8672e-06
# Epoch 834: MSE Loss = 1.8650e-06
# Epoch 835: MSE Loss = 1.8591e-06
# Epoch 836: MSE Loss = 1.8557e-06
# Epoch 837: MSE Loss = 1.8526e-06
# Epoch 838: MSE Loss = 1.8492e-06
# Epoch 839: MSE Loss = 1.8456e-06
# Epoch 840: MSE Loss = 1.8419e-06
# Epoch 841: MSE Loss = 1.8387e-06
# Epoch 842: MSE Loss = 1.8348e-06
# Epoch 843: MSE Loss = 1.8318e-06
# Epoch 844: MSE Loss = 1.8286e-06
# Epoch 845: MSE Loss = 1.8249e-06
# Epoch 846: MSE Loss = 1.8231e-06
# Epoch 847: MSE Loss = 1.8180e-06
# Epoch 848: MSE Loss = 1.8162e-06
# Epoch 849: MSE Loss = 1.8125e-06
# Epoch 850: MSE Loss = 1.8094e-06
# Epoch 851: MSE Loss = 1.8056e-06
# Epoch 852: MSE Loss = 1.8027e-06
# Epoch 853: MSE Loss = 1.7989e-06
# Epoch 854: MSE Loss = 1.7962e-06
# Epoch 855: MSE Loss = 1.7932e-06
# Epoch 856: MSE Loss = 1.7925e-06
# Epoch 857: MSE Loss = 1.7876e-06
# Epoch 858: MSE Loss = 1.7832e-06
# Epoch 859: MSE Loss = 1.7812e-06
# Epoch 860: MSE Loss = 1.7778e-06
# Epoch 861: MSE Loss = 1.7749e-06
# Epoch 862: MSE Loss = 1.7711e-06
# Epoch 863: MSE Loss = 1.7680e-06
# Epoch 864: MSE Loss = 1.7652e-06
# Epoch 865: MSE Loss = 1.7617e-06
# Epoch 866: MSE Loss = 1.7590e-06
# Epoch 867: MSE Loss = 1.7566e-06
# Epoch 868: MSE Loss = 1.7530e-06
# Epoch 869: MSE Loss = 1.7500e-06
# Epoch 870: MSE Loss = 1.7469e-06
# Epoch 871: MSE Loss = 1.7444e-06
# Epoch 872: MSE Loss = 1.7414e-06
# Epoch 873: MSE Loss = 1.7377e-06
# Epoch 874: MSE Loss = 1.7353e-06
# Epoch 875: MSE Loss = 1.7332e-06
# Epoch 876: MSE Loss = 1.7297e-06
# Epoch 877: MSE Loss = 1.7273e-06
# Epoch 878: MSE Loss = 1.7242e-06
# Epoch 879: MSE Loss = 1.7222e-06
# Epoch 880: MSE Loss = 1.7192e-06
# Epoch 881: MSE Loss = 1.7160e-06
# Epoch 882: MSE Loss = 1.7144e-06
# Epoch 883: MSE Loss = 1.7133e-06
# Epoch 884: MSE Loss = 1.7086e-06
# Epoch 885: MSE Loss = 1.7048e-06
# Epoch 886: MSE Loss = 1.7024e-06
# Epoch 887: MSE Loss = 1.6997e-06
# Epoch 888: MSE Loss = 1.6976e-06
# Epoch 889: MSE Loss = 1.6947e-06
# Epoch 890: MSE Loss = 1.6918e-06
# Epoch 891: MSE Loss = 1.6893e-06
# Epoch 892: MSE Loss = 1.6858e-06
# Epoch 893: MSE Loss = 1.6848e-06
# Epoch 894: MSE Loss = 1.7191e-06
# Epoch 895: MSE Loss = 1.6789e-06
# Epoch 896: MSE Loss = 1.6785e-06
# Epoch 897: MSE Loss = 1.6749e-06
# Epoch 898: MSE Loss = 1.6723e-06
# Epoch 899: MSE Loss = 1.6681e-06
# Epoch 900: MSE Loss = 1.6652e-06
# Epoch 901: MSE Loss = 1.6647e-06
# Epoch 902: MSE Loss = 1.6612e-06
# Epoch 903: MSE Loss = 1.6590e-06
# Epoch 904: MSE Loss = 1.6561e-06
# Epoch 905: MSE Loss = 1.6573e-06
# Epoch 906: MSE Loss = 1.6501e-06
# Epoch 907: MSE Loss = 1.6479e-06
# Epoch 908: MSE Loss = 1.6456e-06
# Epoch 909: MSE Loss = 1.6436e-06
# Epoch 910: MSE Loss = 1.6417e-06
# Epoch 911: MSE Loss = 1.6388e-06
# Epoch 912: MSE Loss = 1.6367e-06
# Epoch 913: MSE Loss = 1.6340e-06
# Epoch 914: MSE Loss = 1.6312e-06
# Epoch 915: MSE Loss = 1.6294e-06
# Epoch 916: MSE Loss = 1.6273e-06
# Epoch 917: MSE Loss = 1.6253e-06
# Epoch 918: MSE Loss = 1.6218e-06
# Epoch 919: MSE Loss = 1.6200e-06
# Epoch 920: MSE Loss = 1.6172e-06
# Epoch 921: MSE Loss = 1.6136e-06
# Epoch 922: MSE Loss = 1.6122e-06
# Epoch 923: MSE Loss = 1.6109e-06
# Epoch 924: MSE Loss = 1.6072e-06
# Epoch 925: MSE Loss = 1.6063e-06
# Epoch 926: MSE Loss = 1.6030e-06
# Epoch 927: MSE Loss = 1.6015e-06
# Epoch 928: MSE Loss = 1.5984e-06
# Epoch 929: MSE Loss = 1.5985e-06
# Epoch 930: MSE Loss = 1.5947e-06
# Epoch 931: MSE Loss = 1.5901e-06
# Epoch 932: MSE Loss = 1.5896e-06
# Epoch 933: MSE Loss = 1.5872e-06
# Epoch 934: MSE Loss = 1.5846e-06
# Epoch 935: MSE Loss = 1.5834e-06
# Epoch 936: MSE Loss = 1.5813e-06
# Epoch 937: MSE Loss = 1.5794e-06
# Epoch 938: MSE Loss = 1.5735e-06
# Epoch 939: MSE Loss = 1.5741e-06
# Epoch 940: MSE Loss = 1.5723e-06
# Epoch 941: MSE Loss = 1.5703e-06
# Epoch 942: MSE Loss = 1.5669e-06
# Epoch 943: MSE Loss = 1.5656e-06
# Epoch 944: MSE Loss = 1.5634e-06
# Epoch 945: MSE Loss = 1.5614e-06
# Epoch 946: MSE Loss = 1.5591e-06
# Epoch 947: MSE Loss = 1.5563e-06
# Epoch 948: MSE Loss = 1.5551e-06
# Epoch 949: MSE Loss = 1.5528e-06
# Epoch 950: MSE Loss = 1.5496e-06
# Epoch 951: MSE Loss = 1.5488e-06
# Epoch 952: MSE Loss = 1.5472e-06
# Epoch 953: MSE Loss = 1.5433e-06
# Epoch 954: MSE Loss = 1.5415e-06
# Epoch 955: MSE Loss = 1.5401e-06
# Epoch 956: MSE Loss = 1.5449e-06
# Epoch 957: MSE Loss = 1.5367e-06
# Epoch 958: MSE Loss = 1.5339e-06
# Epoch 959: MSE Loss = 1.5315e-06
# Epoch 960: MSE Loss = 1.5294e-06
# Epoch 961: MSE Loss = 1.5390e-06
# Epoch 962: MSE Loss = 1.5265e-06
# Epoch 963: MSE Loss = 1.5236e-06
# Epoch 964: MSE Loss = 1.5211e-06
# Epoch 965: MSE Loss = 1.5198e-06
# Epoch 966: MSE Loss = 1.5171e-06
# Epoch 967: MSE Loss = 1.5321e-06
# Epoch 968: MSE Loss = 1.5152e-06
# Epoch 969: MSE Loss = 1.5103e-06
# Epoch 970: MSE Loss = 1.5112e-06
# Epoch 971: MSE Loss = 1.5094e-06
# Epoch 972: MSE Loss = 1.5058e-06
# Epoch 973: MSE Loss = 1.5049e-06
# Epoch 974: MSE Loss = 1.5023e-06
# Epoch 975: MSE Loss = 1.4989e-06
# Epoch 976: MSE Loss = 1.5004e-06
# Epoch 977: MSE Loss = 1.4952e-06
# Epoch 978: MSE Loss = 1.4930e-06
# Epoch 979: MSE Loss = 1.4918e-06
# Epoch 980: MSE Loss = 1.4890e-06
# Epoch 981: MSE Loss = 1.4873e-06
# Epoch 982: MSE Loss = 1.4861e-06
# Epoch 983: MSE Loss = 1.4829e-06
# Epoch 984: MSE Loss = 1.4812e-06
# Epoch 985: MSE Loss = 1.4793e-06
# Epoch 986: MSE Loss = 1.4773e-06
# Epoch 987: MSE Loss = 1.4753e-06
# Epoch 988: MSE Loss = 1.4942e-06
# Epoch 989: MSE Loss = 1.4711e-06
# Epoch 990: MSE Loss = 1.4687e-06
# Epoch 991: MSE Loss = 1.4879e-06
# Epoch 992: MSE Loss = 1.4671e-06
# Epoch 993: MSE Loss = 1.4633e-06
# Epoch 994: MSE Loss = 1.4617e-06
# Epoch 995: MSE Loss = 1.4597e-06
# Epoch 996: MSE Loss = 1.4572e-06
# Epoch 997: MSE Loss = 1.4565e-06
# Epoch 998: MSE Loss = 1.4545e-06
# Epoch 999: MSE Loss = 1.4515e-06

# %%
# Plot the learned impulse function
t_plot = torch.linspace(0, T_train[-1], 200)
with torch.no_grad():
    I_learned = torch.stack([my_monkey.net(torch.tensor([[t]], dtype=torch.float32)) 
                             for t in t_plot]).squeeze()

plt.figure(figsize=(15, 10))

# Plot 1: Learned impulse vs true impulse
plt.subplot(2, 2, 1)
plt.plot(t_plot.numpy(), I_learned.numpy(), 'b-', linewidth=2, label='Learned I(t)')
t_true = np.linspace(0, T_train[-1], 200)
I_true = np.array([I(t, 2.5, 0.5) for t in t_true])
plt.plot(t_true, I_true, 'r--', linewidth=2, label='True I(t)')
plt.xlabel('Time')
plt.ylabel('Impulse')
plt.legend()
plt.title('Learned vs True External Impulse')
plt.grid()

# Plot 2: Predictions vs data
plt.subplot(2, 2, 2)
x_pred = odeint(my_monkey, 
                torch.tensor([X_train[0]], dtype=torch.float32).unsqueeze(1),
                T_eval := torch.arange(0,20, 0.01))
plt.plot(T_eval.detach().numpy(), x_pred.detach().numpy().squeeze(), 'b-', linewidth=2, label='UDE Prediction')
plt.plot(T_train, X_train, 'xr', markersize=4, label='Ground Truth Data')

plt.xlabel('Time')
plt.ylabel('Firing Rate')
plt.legend()
plt.title('Firing Rate: Data vs Prediction')
plt.grid()

# Plot 3: losses with semilogy
# NOTE: To obtain this data, I copied the output of the cell that printed the losses and processed it with regex to obtain a readable .csv file by the standards
losses_data = np.loadtxt("./tanh_impulse_losses_processed.txt", delimiter="\t")

plt.subplot(2, 2, 3)
plt.plot(losses_data[:200, 0], losses_data[:200, 1])
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Loss Profile Plot (up to the 200th epoch)")

plt.grid(axis='y')

plt.subplot(2, 2, 4)
plt.semilogy(losses_data[:, 0], losses_data[:, 1])
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Loss Profile Plot (complete)")

plt.grid(axis='y')

plt.show()

# %% [markdown]
# problemi di identificabilità dovuta alla threshold più bassa dell'impulso (oss.)
#
# **TODO: metto threshold = 0.1, 0.05**

# %% [markdown]
# As we can see, this worked! However, an approximation of the activation function was necessary as its gradient tend to vanish under the threshold

# %%
torch.save(my_monkey.state_dict(), "./trained_impulse_nn_relu.dinomeng")

# %% [markdown]
# ### Experiment 2: Only Activation

# %% [markdown]
# Instead of using an ad-hoc surrogate activation function, we can model such function with a neural network. Let's try doing this one with a constant external impulse:

# %%
def firing_rate_threshold(t, data, T, I_ext, J):
    x = data[0]
    activation = np.maximum(0, I_ext+J*x-T)
    return [-x + activation]

T_max = 3

sol = solve_ivp(
    firing_rate_threshold, 
    [0, T_max], (1.,), args=(1, 6, -1), t_eval=np.arange(0, T_max, 0.1),
    rtol = 1e-10, atol=1e-10)

X_train = sol.y[0][::2]
T_train = sol.t[::2]

plt.scatter(T_train, X_train, label="Training Data")

plt.plot(np.arange(0, T_max, 0.1), sol.y[0], label="Solution of the dynamics")

plt.legend()

plt.show()

# %%
class learn_activation(nn.Module):
    def __init__(self, Iext, J):
        super().__init__()

        self.I_ext = Iext 
        self.J = J

        self.net = nn.Sequential(
            nn.Linear(1, 16),
            nn.ReLU(),
            nn.Linear(16, 16),
            nn.ReLU(),
            nn.Linear(16, 16),
            nn.ReLU(),
            nn.Linear(16, 1)
        )

    def forward(self, t, x):
        return -x + self.net(self.I_ext + self.J * x )

# %%
monkey_reaction = learn_activation(
     torch.tensor([6.]), torch.tensor([-1.])
)

lr = 0.003
optimizer = optim.Adam(monkey_reaction.parameters(), lr=lr)

n_epochs = 2000
rtol = 1e-7

t_train_torch = torch.tensor(T_train)

for EPOCH in (range(n_epochs)):
    optimizer.zero_grad()
    monkey_reaction.zero_grad()
    
    # forward solution
    x_pred = odeint(monkey_reaction, 
                    torch.tensor([1.], requires_grad=False),
                    t_train_torch,
                    rtol=rtol
                    )
    
    # Compute loss at training points
    loss = torch.tensor(0., requires_grad=True)
    for i, (t, x_true) in enumerate(zip(T_train, X_train)):
        loss = loss + (x_pred[i] - x_true) ** 2
    
    loss = loss / len(T_train)
    
    # Backpropagate
    loss.backward()
    optimizer.step()
    
    print(f"{EPOCH}\t{loss.item():.4e}")
# Out:
# 0	4.5863e+00
# 1	4.5066e+00
# 2	4.4379e+00
# 3	4.3695e+00
# 4	4.2997e+00
# 5	4.2289e+00
# 6	4.1584e+00
# 7	4.0889e+00
# 8	4.0345e+00
# 9	3.9815e+00
# 10	3.9253e+00
# 11	3.8622e+00
# 12	3.7964e+00
# 13	3.7277e+00
# 14	3.6542e+00
# 15	3.5757e+00
# 16	3.4919e+00
# 17	3.4026e+00
# 18	3.3078e+00
# 19	3.2071e+00
# 20	3.1006e+00
# 21	2.9882e+00
# 22	2.8699e+00
# 23	2.7457e+00
# 24	2.6157e+00
# 25	2.4803e+00
# 26	2.3397e+00
# 27	2.1944e+00
# 28	2.0450e+00
# 29	1.8924e+00
# 30	1.7373e+00
# 31	1.5810e+00
# 32	1.4246e+00
# 33	1.2696e+00
# 34	1.1174e+00
# 35	9.6953e-01
# 36	8.2770e-01
# 37	6.9351e-01
# 38	5.6853e-01
# 39	4.5419e-01
# 40	3.5170e-01
# 41	2.6207e-01
# 42	1.8595e-01
# 43	1.2193e-01
# 44	7.1923e-02
# 45	3.6117e-02
# 46	1.3901e-02
# 47	4.0087e-03
# 48	4.5646e-03
# 49	1.3098e-02
# 50	2.6635e-02
# 51	4.2231e-02
# 52	5.7475e-02
# 53	7.0622e-02
# 54	8.0569e-02
# 55	8.6775e-02
# 56	8.9156e-02
# 57	8.7977e-02
# 58	8.3747e-02
# 59	7.7118e-02
# 60	6.8800e-02
# 61	5.9491e-02
# 62	5.0459e-02
# 63	4.2369e-02
# 64	3.4506e-02
# 65	2.7207e-02
# 66	2.0724e-02
# 67	1.5218e-02
# 68	1.0772e-02
# 1910	1.0064e-09
# 1911	1.0424e-09
# 1912	1.0525e-09
# 1913	1.0402e-09
# 1914	1.0026e-09
# 1915	1.0661e-09
# 1916	1.0711e-09
# 1917	1.0601e-09
# 1918	1.0409e-09
# 1919	1.0338e-09
# 1920	1.0601e-09
# 1921	1.0483e-09
# 1922	1.0562e-09
# 1923	1.0531e-09
# 1924	1.0471e-09
# 1925	1.0512e-09
# 1926	1.0141e-09
# 1927	1.0431e-09
# 1928	1.0103e-09
# 1929	1.0486e-09
# 1930	1.0736e-09
# 1931	1.0578e-09
# 1932	1.0481e-09
# 1933	1.0221e-09
# 1934	1.0751e-09
# 1935	1.0549e-09
# 1936	1.0572e-09
# 1937	1.0556e-09
# 1938	9.8283e-10
# 1939	1.0050e-09
# 1940	1.0581e-09
# 1941	1.0255e-09
# 1942	1.0527e-09
# 1943	1.0795e-09
# 1944	9.9923e-10
# 1945	1.0029e-09
# 1946	1.0338e-09
# 1947	1.0437e-09
# 1948	1.0498e-09
# 1949	1.0597e-09
# 1950	9.9469e-10
# 1951	1.0306e-09
# 1952	1.0707e-09
# 1953	9.9716e-10
# 1954	1.0119e-09
# 1955	1.0295e-09
# 1956	1.0516e-09
# 1957	1.0284e-09
# 1958	1.0523e-09
# 1959	1.0469e-09
# 1960	1.0185e-09
# 1961	1.0524e-09
# 1962	1.0001e-09
# 1963	1.0399e-09
# 1964	1.0394e-09
# 1965	1.0270e-09
# 1966	1.0399e-09
# 1967	1.0637e-09
# 1968	1.0345e-09
# 1969	1.0327e-09
# 1970	9.7824e-10
# 1971	1.0530e-09
# 1972	1.0348e-09
# 1973	1.0385e-09
# 1974	1.0149e-09
# 1975	1.0360e-09
# 1976	1.0417e-09
# 1977	1.0520e-09
# 1978	9.8807e-10
# 1979	1.0468e-09
# 1980	1.0379e-09
# 1981	1.0334e-09
# 1982	1.0081e-09
# 1983	1.0385e-09
# 1984	1.0379e-09
# 1985	1.0331e-09
# 1986	1.0384e-09
# 1987	1.0258e-09
# 1988	1.0556e-09
# 1989	1.0181e-09
# 1990	1.0261e-09
# 1991	9.7470e-10
# 1992	1.0448e-09
# 1993	1.0695e-09
# 1994	1.0722e-09
# 1995	1.0054e-09
# 1996	1.0076e-09
# 1997	1.0461e-09
# 1998	1.0234e-09
# 1999	1.0492e-09

# %%
torch.save(monkey_reaction.state_dict(), "./trained_activation_nn.dinomeng")

# %%
# Plot the transfer function
i_plot = torch.arange(-10, 10, 0.1)
with torch.no_grad():
    act_learned = torch.stack([monkey_reaction.net(torch.tensor([[I]], dtype=torch.float32)) 
                             for I in i_plot]).squeeze()

plt.figure(figsize=(15, 10))

# Plot 1: Learned Activation vs true activation
plt.subplot(2, 2, 1)
plt.plot(i_plot.numpy(), act_learned.numpy(), 'b-', linewidth=2, label='Learned F(t)')

i_true = np.arange(-10, 10, 0.1)

act_true = np.maximum(0, i_true)

plt.plot(i_true, act_true, 'r--', linewidth=2, label='True F(t)')
plt.xlabel('Time')
plt.ylabel('Impulse')
plt.legend()
plt.title('Learned vs True Transfer Function')
plt.grid()

# Plot 2: Predictions vs data
plt.subplot(2, 2, 2)
x_pred = odeint(monkey_reaction, 
                torch.tensor([X_train[0]], dtype=torch.float32).unsqueeze(1),
                T_eval := torch.arange(0,3, 0.01))

plt.plot(T_eval.detach().numpy(), x_pred.detach().numpy().squeeze(), 'b-', linewidth=2, label='UDE Prediction')
plt.plot(T_train, X_train, 'xr', markersize=4, label='Ground Truth Data')

plt.xlabel('Time')
plt.ylabel('Firing Rate')
plt.legend()
plt.title('Firing Rate: Data vs Prediction')
plt.grid()

# Plot 3: losses with semilogy
losses_data = np.loadtxt("./trained_activation_losses.txt", delimiter="\t")

plt.subplot(2, 2, 3)
plt.semilogy(losses_data[:, 0], losses_data[:, 1])
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.axhline(2**(-23), linestyle="--", color='r', label="Unit Roundoff in F32")
plt.legend()

plt.title("Loss Profile Plot (complete)")
plt.grid(axis='y')

plt.show()

# %% [markdown]
# todo: provare con altri iperparametri della rete
#
# vedo tool per fine tuning applicato a questo caso (diff. eqs)

# %% [markdown]
# ### Experiment 3: Both

# %%
# Now let's try doing both at the same time: learn both the impulse function and the transfer function at the same time

# %%
def firing_rate_threshold(t, data, T, I_ext, J):
    x = data[0]
    activation = np.maximum(0, I_ext(t)+J*x-T)
    return [-x + activation]

def I(t, t_peak, sigma):
    return 2.0 * np.exp(-((t - t_peak)**2) / (2 * sigma**2)) 
    
T_max = 12

sol = solve_ivp(
    firing_rate_threshold, 
    [0, T_max], (0.,), args=(1.5, lambda t: I(t, 5, 2), -1), t_eval=np.arange(0, T_max, 0.1),
    rtol = 1e-8, atol=1e-8)

plt.plot(sol.t, sol.y[0])

X_train = sol.y[0][::5]
T_train = sol.t[::5]

plt.scatter(T_train, X_train)

plt.show()

# %%
class learn_all(nn.Module):
    def __init__(self, J):
        super().__init__()

        self.J = J

        self.net_transfer = nn.Sequential(
            nn.Linear(1, 16),
            nn.ReLU(),
            nn.Linear(16, 16),
            nn.ReLU(),
            nn.Linear(16, 1)
        )

        self.net_impulse = nn.Sequential(
            nn.Linear(1, 16),
            nn.Tanh(),
            nn.Linear(16, 32),
            nn.Tanh(),
            nn.Linear(32, 32),
            nn.Tanh(),
            nn.Linear(32, 16),
            nn.Tanh(),
            nn.Linear(16, 1)
        )


    def forward(self, t, x):
        return -x + self.net_transfer(self.net_impulse(t.reshape(1, 1)) + self.J * x )

# %%
advanced_monkey = learn_all(
    torch.tensor([-1.]),
)

lr = 0.0005


optimizer = optim.Adam(advanced_monkey.parameters(), lr=lr)


n_epochs = 1000
rtol = 1e-7

t_train_torch = torch.tensor(T_train)

for EPOCH in (range(n_epochs)):
    optimizer.zero_grad()
    advanced_monkey.zero_grad()
    
    # forward solution
    x_pred = odeint(advanced_monkey, 
                    torch.tensor([0.], requires_grad=False),
                    t_train_torch,
                    rtol=rtol
                    )
    
    # Compute loss at training points
    loss = torch.tensor(0., requires_grad=True)
    for i, (t, x_true) in enumerate(zip(T_train, X_train)):
        loss = loss + (x_pred[i] - x_true) ** 2
# 584	9.5513176e-05
# 585	9.4447627e-05
# 586	9.3406961e-05
# 587	9.2364964e-05
# 588	9.1354887e-05
# 589	9.0350251e-05
# 590	8.9370944e-05
# 591	8.8398338e-05
# 592	8.7444634e-05
# 593	8.6496671e-05
# 594	8.5568936e-05
# 595	8.4651838e-05
# 596	8.3754079e-05
# 597	8.2872655e-05
# 598	8.2004022e-05
# 599	8.1129539e-05
# 600	8.0290542e-05
# 601	7.9456986e-05
# 602	7.8634977e-05
# 603	7.7825309e-05
# 604	7.7030993e-05
# 605	7.6240445e-05
# 606	7.5474258e-05
# 607	7.4708696e-05
# 608	7.3956740e-05
# 609	7.3226212e-05
# 610	7.2495568e-05
# 611	7.1781389e-05
# 612	7.1083261e-05
# 613	7.0380520e-05
# 614	6.9707276e-05
# 615	6.9034308e-05
# 616	6.8371512e-05
# 617	6.7716370e-05
# 618	6.7070039e-05
# 619	6.6434033e-05
# 620	6.5806955e-05
# 621	6.5196167e-05
# 622	6.4593296e-05
# 623	6.3994448e-05
# 624	6.3408152e-05
# 625	6.2831990e-05
# 626	6.2261650e-05
# 627	6.1692670e-05
# 628	6.1149934e-05
# 629	6.0597071e-05
# 630	6.0065478e-05
# 631	5.9535083e-05
# 632	5.9009326e-05
# 633	5.8498161e-05
# 634	5.7991794e-05
# 635	5.7494355e-05
# 636	5.7002111e-05
# 637	5.6515888e-05
# 638	5.6042718e-05
# 639	5.5569308e-05
# 640	5.5108627e-05
# 641	5.4649707e-05
# 642	5.4200518e-05
# 643	5.3757900e-05
# 644	5.3318265e-05
# 645	5.2896270e-05
# 646	5.2465472e-05
# 647	5.2044950e-05
# 648	5.1668871e-05
# 649	5.1232277e-05
# 650	5.0828068e-05
# 651	5.0439077e-05
# 652	5.0046627e-05
# 653	4.9663195e-05
# 654	4.9288126e-05
# 655	4.8917300e-05
# 656	4.8546295e-05
# 657	4.8187754e-05
# 658	4.7837093e-05
# 659	4.7479261e-05
# 660	4.7136378e-05
# 661	4.6792207e-05
# 662	4.6458201e-05
# 663	4.6123027e-05
# 664	4.5799836e-05
# 665	4.5477831e-05
# 666	4.5160152e-05
# 667	4.4844313e-05
# 668	4.4531684e-05
# 669	4.4233704e-05
# 670	4.3927528e-05
# 671	4.3634598e-05
# 672	4.3343145e-05
# 673	4.3054912e-05
# 674	4.2774165e-05
# 675	4.2489253e-05
# 676	4.2217918e-05
# 677	4.1945608e-05
# 678	4.1674826e-05
# 679	4.1412844e-05
# 680	4.1153962e-05
# 681	4.0898900e-05
# 682	4.0640789e-05
# 683	4.0392599e-05
# 684	4.0149393e-05
# 685	3.9907369e-05
# 686	3.9662762e-05
# 687	3.9427541e-05
# 688	3.9192313e-05
# 689	3.8968563e-05
# 690	3.8740989e-05
# 691	3.8518145e-05
# 692	3.8297872e-05
# 693	3.8082482e-05
# 694	3.7869799e-05
# 695	3.7656908e-05
# 696	3.7449023e-05
# 697	3.7246911e-05
# 698	3.7068512e-05
# 699	3.6844212e-05
# 700	3.6643145e-05
# 701	3.6450783e-05
# 702	3.6258600e-05
# 703	3.6068759e-05
# 704	3.5879577e-05
# 705	3.5695204e-05
# 706	3.5514826e-05
# 707	3.5334931e-05
# 708	3.5157860e-05
# 709	3.4984027e-05
# 710	3.4814952e-05
# 711	3.4640692e-05
# 712	3.4474651e-05
# 713	3.4311954e-05
# 714	3.4146822e-05
# 715	3.3982975e-05
# 716	3.3823202e-05
# 717	3.3670458e-05
# 718	3.3512857e-05
# 719	3.3361346e-05
# 720	3.3212029e-05
# 721	3.3063854e-05
# 722	3.2914329e-05
# 723	3.2770553e-05
# 724	3.2624925e-05
# 725	3.2484877e-05
# 726	3.2346088e-05
# 727	3.2206492e-05
# 728	3.2068627e-05
# 729	3.1937718e-05
# 730	3.1801181e-05
# 731	3.1670050e-05
# 732	3.1539577e-05
# 733	3.1413296e-05
# 734	3.1286141e-05
# 735	3.1155283e-05
# 736	3.1035855e-05
# 737	3.0915002e-05
# 738	3.0793144e-05
# 739	3.0673804e-05
# 740	3.0555148e-05
# 741	3.0440613e-05
# 742	3.0324307e-05
# 743	3.0212015e-05
# 744	3.0099756e-05
# 745	2.9988258e-05
# 746	2.9875358e-05
# 747	2.9771158e-05
# 748	2.9658599e-05
# 749	2.9557910e-05
# 750	2.9450204e-05
# 751	2.9344012e-05
# 752	2.9242874e-05
# 753	2.9143865e-05
# 754	2.9041947e-05
# 755	2.8944809e-05
# 756	2.8844450e-05
# 757	2.8752460e-05
# 758	2.8652408e-05
# 759	2.8557051e-05
# 760	2.8463159e-05
# 761	2.8373723e-05
# 762	2.8280485e-05
# 763	2.8189172e-05
# 764	2.8095092e-05
# 765	2.8009466e-05
# 766	2.7919741e-05
# 767	2.7834714e-05
# 768	2.7747546e-05
# 769	2.7661850e-05
# 770	2.7578126e-05
# 771	2.7493310e-05
# 772	2.7410684e-05
# 773	2.7330259e-05
# 774	2.7254842e-05
# 775	2.7166718e-05
# 776	2.7089052e-05
# 777	2.7011343e-05
# 778	2.6930398e-05
# 779	2.6854332e-05
# 780	2.6778531e-05
# 781	2.6703361e-05
# 782	2.6629197e-05
# 783	2.6553294e-05
# 784	2.6480244e-05
# 785	2.6406642e-05
# 786	2.6338712e-05
# 787	2.6263819e-05
# 788	2.6193668e-05
# 789	2.6123758e-05
# 790	2.6057343e-05
# 791	2.5987676e-05
# 792	2.5920881e-05
# 793	2.5853105e-05
# 794	2.5786263e-05
# 795	2.5720563e-05
# 796	2.5654646e-05
# 797	2.5589288e-05
# 798	2.5526342e-05
# 799	2.5462125e-05
# 800	2.5400053e-05
# 801	2.5357724e-05
# 802	2.5276182e-05
# 803	2.5215626e-05
# 804	2.5155596e-05
# 805	2.5094783e-05
# 806	2.5034164e-05
# 807	2.4975467e-05
# 808	2.4917254e-05
# 809	2.4861709e-05
# 810	2.4804591e-05
# 811	2.4747305e-05
# 812	2.4690824e-05
# 813	2.4634204e-05
# 814	2.4577392e-05
# 815	2.4523784e-05
# 816	2.4470626e-05
# 817	2.4416835e-05
# 818	2.4365450e-05
# 819	2.4310359e-05
# 820	2.4257561e-05
# 821	2.4207082e-05
# 822	2.4156363e-05
# 823	2.4105158e-05
# 824	2.4053445e-05
# 825	2.4003282e-05
# 826	2.3955703e-05
# 827	2.3906881e-05
# 828	2.3855611e-05
# 829	2.3809300e-05
# 830	2.3758637e-05
# 831	2.3712339e-05
# 832	2.3667626e-05
# 833	2.3618975e-05
# 834	2.3571418e-05
# 835	2.3524715e-05
# 836	2.3480437e-05
# 837	2.3434848e-05
# 838	2.3390648e-05
# 839	2.3344808e-05
# 840	2.3324066e-05
# 841	2.3280967e-05
# 842	2.3212438e-05
# 843	2.3170440e-05
# 844	2.3131068e-05
# 845	2.3084300e-05
# 846	2.3041290e-05
# 847	2.3001629e-05
# 848	2.2959504e-05
# 849	2.2915077e-05
# 850	2.2877533e-05
# 851	2.2835462e-05
# 852	2.2795981e-05
# 853	2.2754115e-05
# 854	2.2715760e-05
# 855	2.2676244e-05
# 856	2.2636326e-05
# 857	2.2599081e-05
# 858	2.2558661e-05
# 859	2.2520720e-05
# 860	2.2480497e-05
# 861	2.2444328e-05
# 862	2.2404502e-05
# 863	2.2367900e-05
# 864	2.2331120e-05
# 865	2.2295118e-05
# 866	2.2257134e-05
# 867	2.2220032e-05
# 868	2.2185683e-05
# 869	2.2147529e-05
# 870	2.2112310e-05
# 871	2.2078202e-05
# 872	2.2042268e-05
# 873	2.2005634e-05
# 874	2.1971739e-05
# 875	2.1934457e-05
# 876	2.1903412e-05
# 877	2.1868205e-05
# 878	2.1833621e-05
# 879	2.1798574e-05
# 880	2.1764732e-05
# 881	2.1731006e-05
# 882	2.1700364e-05
# 883	2.1666679e-05
# 884	2.1636208e-05
# 885	2.1598527e-05
# 886	2.1565125e-05
# 887	2.1532762e-05
# 888	2.1501748e-05
# 889	2.1468773e-05
# 890	2.1435691e-05
# 891	2.1404790e-05
# 892	2.1372662e-05
# 893	2.1341204e-05
# 894	2.1309503e-05
# 895	2.1277183e-05
# 896	2.1249589e-05
# 897	2.1215645e-05
# 898	2.1184629e-05
# 899	2.1153237e-05
# 900	2.1123813e-05
# 901	2.1090958e-05
# 902	2.1064719e-05
# 903	2.1030186e-05
# 904	2.1003072e-05
# 905	2.0970590e-05
# 906	2.0939842e-05
# 907	2.0912783e-05
# 908	2.0882386e-05
# 909	2.0852071e-05
# 910	2.0823902e-05
# 911	2.0795260e-05
# 912	2.0766282e-05
# 913	2.0736930e-05
# 914	2.0709134e-05
# 915	2.0679305e-05
# 916	2.0649977e-05
# 917	2.0621170e-05
# 918	2.0594678e-05
# 919	2.0564408e-05
# 920	2.0537422e-05
# 921	2.0508793e-05
# 922	2.0479603e-05
# 923	2.0453583e-05
# 924	2.0423618e-05
# 925	2.0397623e-05
# 926	2.0366131e-05
# 927	2.0341631e-05
# 928	2.0313781e-05
# 929	2.0289164e-05
# 930	2.0260133e-05
# 931	2.0232657e-05
# 932	2.0204330e-05
# 933	2.0181325e-05
# 934	2.0150508e-05
# 935	2.0123145e-05
# 936	2.0096146e-05
# 937	2.0070114e-05
# 938	2.0044152e-05
# 939	2.0017937e-05
# 940	1.9990339e-05
# 941	1.9964917e-05
# 942	1.9936722e-05
# 943	1.9913732e-05
# 944	1.9886318e-05
# 945	1.9856852e-05
# 946	1.9832893e-05
# 947	1.9809126e-05
# 948	1.9783516e-05
# 949	1.9757665e-05
# 950	1.9731799e-05
# 951	1.9705736e-05
# 952	1.9679990e-05
# 953	1.9654673e-05
# 954	1.9628380e-05
# 955	1.9603189e-05
# 956	1.9577548e-05
# 957	1.9554182e-05
# 958	1.9527923e-05
# 959	1.9502482e-05
# 960	1.9477488e-05
# 961	1.9453159e-05
# 962	1.9426385e-05
# 963	1.9399546e-05
# 964	1.9376923e-05
# 965	1.9353751e-05
# 966	1.9329376e-05
# 967	1.9303590e-05
# 968	1.9280909e-05
# 969	1.9253941e-05
# 970	1.9231702e-05
# 971	1.9208286e-05
# 972	1.9178973e-05
# 973	1.9157538e-05
# 974	1.9129497e-05
# 975	1.9107543e-05
# 976	1.9083120e-05
# 977	1.9058036e-05
# 978	1.9036581e-05
# 979	1.9011766e-05
# 980	1.8986191e-05
# 981	1.8963869e-05
# 982	1.8939652e-05
# 983	1.8915274e-05
# 984	1.8893325e-05
# 985	1.8867284e-05
# 986	1.8845867e-05
# 987	1.8822759e-05
# 988	1.8797005e-05
# 989	1.8774697e-05
# 990	1.8750659e-05
# 991	1.8727033e-05
# 992	1.8704914e-05
# 993	1.8676777e-05
# 994	1.8657758e-05
# 995	1.8632280e-05
# 996	1.8611498e-05
# 997	1.8588033e-05
# 998	1.8563156e-05
# 999	1.8538465e-05

# %%
# just 500 more epochs bro
for EPOCH in (range(1000, 1500)):
    optimizer.zero_grad()
    advanced_monkey.zero_grad()
    
    # forward solution
    x_pred = odeint(advanced_monkey, 
                    torch.tensor([0.], requires_grad=False),
                    t_train_torch,
                    rtol=rtol
                    )
    
    # Compute loss at training points
    loss = torch.tensor(0., requires_grad=True)
    for i, (t, x_true) in enumerate(zip(T_train, X_train)):
        loss = loss + (x_pred[i] - x_true) ** 2
    
    loss = loss / len(T_train)
    
    # Backpropagate
    loss.backward()
    optimizer.step()

    print(f"{EPOCH}\t{loss.item():.7e}")
# Out:
# 1000	1.8516383e-05
# 1001	1.8494076e-05
# 1002	1.8470048e-05
# 1003	1.8449120e-05
# 1004	1.8427256e-05
# 1005	1.8402719e-05
# 1006	1.8376964e-05
# 1007	1.8355096e-05
# 1008	1.8332874e-05
# 1009	1.8311159e-05
# 1010	1.8287597e-05
# 1011	1.8265402e-05
# 1012	1.8243654e-05
# 1013	1.8221595e-05
# 1014	1.8198583e-05
# 1015	1.8173883e-05
# 1016	1.8153345e-05
# 1017	1.8129207e-05
# 1018	1.8109309e-05
# 1019	1.8085360e-05
# 1020	1.8061504e-05
# 1021	1.8041612e-05
# 1022	1.8018907e-05
# 1023	1.7997378e-05
# 1024	1.7972172e-05
# 1025	1.7951725e-05
# 1026	1.7929529e-05
# 1027	1.7908011e-05
# 1028	1.7884817e-05
# 1029	1.7865508e-05
# 1468	1.0308623e-05
# 1469	1.0293473e-05
# 1470	1.0279542e-05
# 1471	1.0263014e-05
# 1472	1.0250304e-05
# 1473	1.0237892e-05
# 1474	1.0226453e-05
# 1475	1.0210789e-05
# 1476	1.0198470e-05
# 1477	1.0181838e-05
# 1478	1.0169236e-05
# 1479	1.0156429e-05
# 1480	1.0140941e-05
# 1481	1.0128078e-05
# 1482	1.0114120e-05
# 1483	1.0099124e-05
# 1484	1.0087377e-05
# 1485	1.0073092e-05
# 1486	1.0058204e-05
# 1487	1.0044473e-05
# 1488	1.0033636e-05
# 1489	1.0017850e-05
# 1490	1.0005714e-05
# 1491	9.9905637e-06
# 1492	9.9866402e-06
# 1493	9.9632880e-06
# 1494	9.9511481e-06
# 1495	9.9377557e-06
# 1496	9.9235067e-06
# 1497	9.9107938e-06
# 1498	9.8975752e-06
# 1499	9.8847586e-06

# %%
# JUST ANOTHER 500 epochs bro trust me (also increase learning rate by a ltitle bit)
lr = 0.001
optimizer = optim.Adam(advanced_monkey.parameters(), lr=lr)


n_epochs = 1000
rtol = 1e-7

t_train_torch = torch.tensor(T_train)

for EPOCH in range(1500, 2000):
    optimizer.zero_grad()
    advanced_monkey.zero_grad()
    
    # forward solution
    x_pred = odeint(advanced_monkey, 
                    torch.tensor([0.], requires_grad=False),
                    t_train_torch,
                    rtol=rtol
                    )
    
    # Compute loss at training points
    loss = torch.tensor(0., requires_grad=True)
    for i, (t, x_true) in enumerate(zip(T_train, X_train)):
        loss = loss + (x_pred[i] - x_true) ** 2
    
    loss = loss / len(T_train)
    
    # Backpropagate
    loss.backward()
    optimizer.step()

    print(f"{EPOCH}\t{loss.item():.7e}")
# Out:
# 1500	3.4731292e-04
# 1501	1.3938674e-04
# 1502	2.4861327e-04
# 1503	5.2689629e-05
# 1504	3.5236022e-05
# 1505	1.3305320e-04
# 1506	1.3102520e-04
# 1507	4.9337163e-05
# 1508	9.5770529e-06
# 1509	4.7488236e-05
# 1510	8.4114406e-05
# 1511	6.0916122e-05
# 1512	1.8882691e-05
# 1513	1.3319125e-05
# 1514	3.9001756e-05
# 1515	5.2941876e-05
# 1516	3.7015885e-05
# 1517	1.3549929e-05
# 1518	1.0536666e-05
# 1519	2.6506716e-05
# 1520	3.5419198e-05
# 1521	2.4945643e-05
# 1522	1.0716387e-05
# 1523	1.0197244e-05
# 1524	1.9898025e-05
# 1525	2.4154562e-05
# 1526	1.7414481e-05
# 1527	9.4240668e-06
# 1528	1.0128607e-05
# 1529	1.6318614e-05
# 1530	1.7597828e-05
# 1531	1.2198084e-05
# 1532	8.1427615e-06
# 1533	1.0236214e-05
# 1534	1.3968340e-05
# 1535	1.3422185e-05
# 1536	9.6675676e-06
# 1537	8.1261824e-06
# 1538	1.0219593e-05
# 1539	1.1836152e-05
# 1540	1.0290783e-05
# 1541	8.1913859e-06
# 1542	8.5692709e-06
# 1543	1.0176514e-05
# 1544	1.0098503e-05
# 1545	8.4957410e-06
# 1546	7.8785424e-06
# 1547	8.8597053e-06
# 1548	9.4529223e-06
# 1987	5.8217472e-07
# 1988	5.7507538e-07
# 1989	5.6872142e-07
# 1990	5.6174645e-07
# 1991	5.5490165e-07
# 1992	5.4913545e-07
# 1993	5.4176064e-07
# 1994	5.3537116e-07
# 1995	5.2894296e-07
# 1996	5.2246276e-07
# 1997	5.1608532e-07
# 1998	5.0987961e-07
# 1999	5.0368720e-07

# %%
# Plot the learned impulse function
t_plot = torch.linspace(0, T_train[-1], 200)
with torch.no_grad():
    I_learned = torch.stack([advanced_monkey.net_impulse(torch.tensor([[t]], dtype=torch.float32)) 
                             for t in t_plot]).squeeze()

plt.figure(figsize=(15, 10))

# Plot 1: Learned impulse vs true impulse
plt.subplot(2, 2, 1)
plt.plot(t_plot.numpy(), I_learned.numpy(), 'b-', linewidth=2, label='Learned I(t)')
t_true = np.linspace(0, T_train[-1], 200)
I_true = np.array([I(t, 5, 2) for t in t_true])
plt.plot(t_true, I_true, 'r--', linewidth=2, label='True I(t)')
plt.xlabel('Time')
plt.ylabel('Impulse')
plt.legend()
plt.title('Learned vs True External Impulse')
plt.grid()

# Plot the transfer function
i_plot = torch.arange(-20, 10, 0.1)
with torch.no_grad():
    act_learned = torch.stack([advanced_monkey.net_transfer(torch.tensor([[I]], dtype=torch.float32)) 
                             for I in i_plot]).squeeze()

# Plot 2: Learned Activation vs true activation
plt.subplot(2, 2, 2)
plt.plot(i_plot.numpy(), act_learned.numpy(), 'b-', linewidth=2, label='Learned F(t)')

i_true = np.arange(-20, 10, 0.1)

act_true = np.maximum(0, i_true)

plt.plot(i_true, act_true, 'r--', linewidth=2, label='True F(t)')
plt.xlabel('Time')
plt.ylabel('Impulse')
plt.legend()
plt.title('Learned vs True Activation')
plt.grid()


# Plot 3: Predictions vs data
plt.subplot(2, 2, 3)
x_pred = odeint(advanced_monkey, 
                torch.tensor([X_train[0]], dtype=torch.float32).unsqueeze(1),
                T_eval := torch.arange(0,13, 0.01))
plt.plot(T_eval.detach().numpy(), x_pred.detach().numpy().squeeze(), 'b-', linewidth=2, label='UDE Prediction')
plt.plot(T_train, X_train, 'xr', markersize=4, label='Ground Truth Data')
plt.plot(sol.t, sol.y[0], 'r--', markersize=4, label='Ground Truth Dynamics')

plt.xlabel('Time')
plt.ylabel('Firing Rate')
plt.legend()
plt.title('Firing Rate: Data vs Prediction')
plt.grid()

# Plot 3: losses with semilogy
# NOTE: To obtain this data, I copied the output of the cell that printed the losses and processed it with regex to obtain a readable .csv file by the standards
losses_data = np.loadtxt("./trained_advanced_monkey_losses.txt", delimiter="\t")

plt.subplot(2, 2, 4)
plt.semilogy(losses_data[:, 0], losses_data[:, 1])
plt.xlabel("Epoch")
plt.ylabel("Loss")

plt.grid(axis='y')

plt.show()

# %% [markdown]
# > **N.B.** At the 1500th epoch I have reinstantiated the optimizer with a new learning rate, which is the likely cause of the destabilization in the loss at thes epochs

# %%
torch.save(advanced_monkey.state_dict(), "./advanced_monkey_trained.dinomeng")

# %%
# Remark: The learned functions seem to not match, however if we "flip" them they will result to be correct. 
# Maybe due to the fact that we are learning TWO NNs -> equivalency in scale (?????)
